# %% [markdown]
# ## Variables and Data Structures
# ### BIOINF 575

# %% [markdown]
# ### Interactive python apps commands
#
# * anaconda-navigator – launch the Anaconda Navigator
#
# * python – open a plain python console in current terminal
# * http://jupyter.org/ - The evolved form of iPython
#     * ipython or jupyter-console – open an iPython console in the current terminal
#     * jupyter-qtconsole – open an iPython session in a qt console (console uses qt GUI library, more functional window)
#     * jupyter-notebook – start a notebook session and open in in a web browser
#     * jupyter lab – start a jupyter lab session, the evolution of the notebook
#     * spyder – launch the Spyder IDE - https://www.spyder-ide.org/

# %% [markdown]
# https://www.dataquest.io/blog/jupyter-notebook-tutorial/

# %% [markdown]
# https://jupyterlab.readthedocs.io/en/stable/

# %% [markdown]
# ### Visual Studio Code can also be used as an IDE
# - https://code.visualstudio.com/download
# - https://code.visualstudio.com/docs
#
# <img src="vscode_notebook.png" width = "700pt" >

# %% [markdown]
# ### Jupyter lab - quick info

# %% [markdown]
# Two types of cells:
# * <b>markdown</b> - write description for the code
# * <b>code</b> - write the code
#
#
# Useful info:
# * Click on the blue bar on the left side of a cell collapses the content or expands the content if it is collapsed

# %% [markdown]
# | Quick keys    | mode    | action                                  |
# |---------------|---------|-----------------------------------------|
# | Esc - m       | command | switch cell to Markdown cell            |
# | Esc - y       | command | switch cell to code cell                |
# | Esc - a       | command | insert cell above                       |
# | Esc - b       | command | insert cell below                       |
# | Esc - d - d   | command | delete cell                             |
# | Shift + Enter | edit    | execute cell and move to the cell below |
# | Alt + Enter   | edit    | execute cell and insert a cell below    |

# %% [markdown]
# A <b>markup language</b> is a system for annotating a document where the text does not read very well but the result makes the content easier to understand<br>
# Example: using color, different font styles, different font size, indentation, itemizing, numbering
# The idea started from the "marking up" of paper manuscripts.
#
# <b>Markdown</b> is a tool to convert text to HTML.<br>
# Markdown is lightweight markup language with plain text formatting syntax.<br>
# Its design allows it to be converted to many output formats, but the original tool by the same name only supports HTML.<br>
# Markdown is often used to format readme files, for writing messages in online discussion forums, and to create rich text using a plain text editor.<br><br>
#
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
#
# https://markdown.land/markdown-cheat-sheet

# %% [markdown]
# Use the <b>\<Kernel\></b> menu options to:
# * restart kernel (clear/reset the environemnt)
# * clear all cell outputs
# * rerun all cells.

# %% [markdown]
# ____
#
# ### Instructions about python code:

# %% [markdown]
# ##### Use import to bring in/import functionality from an existing source/package

# %% [markdown]
# ##### We will have a session on building packages and modules with more details about this
#
# ```python
# # import all module(s) functionality
#
# import module1_name[, module2_name[,... moduleN_name]
#
# # import specific item/function from module
#
# from module_name import name1[, name2[, ... nameN]]
#
# # Not recommended
# # import all module functionality but once imported
# # you will not know which module it came from
#
# from module_name import *
# ```
#
# https://www.tutorialspoint.com/python/python_modules.htm

# %% [markdown]
# #### The Zen of Python, by Tim Peters

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
# %who
# Out:
# NamespaceMagics	 dataframe_columns	 dataframe_hash	 dtypes_str	 get_dataframes	 get_ipython	 getpass	 hashlib	 import_pandas_safely
# is_data_frame	 json	 sys	 this

# %%
import my_module
# Out:
# I'm in my module

# %%
# %whos
# Out:
# Variable               Type             Data/Info
# -------------------------------------------------
# NamespaceMagics        MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# dataframe_columns      function         <function dataframe_columns at 0x1352fd080>
# dataframe_hash         function         <function dataframe_hash at 0x1352fc360>
# dtypes_str             function         <function dtypes_str at 0x1352fcd60>
# get_dataframes         function         <function get_dataframes at 0x1352fc180>
# get_ipython            function         <function get_ipython at 0x106f7d3a0>
# getpass                module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely   function         <function import_pandas_safely at 0x1352fd580>
# is_data_frame          function         <function is_data_frame at 0x1352fd260>
# json                   module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# my_module              module           <module 'my_module' from <...>data_types/my_module.py'>
# sys                    module           <module 'sys' (built-in)>
# this                   module           <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %%
my_module.my_test_variable
# Out:
# 5

# %%
my_module.my_test_variable = 7

# %%
my_module.my_test_variable
# Out:
# 7

# %% [markdown]
# #### Python - Data types
#
# Typing is dynamic but strict in python (everything is an object and objects have type).<br><br>
# The principal built-in types are numerics, sequences, mappings, classes, instances and exceptions.<br>
# Numeric Types — int (subtype: bool), float, complex.<br>
# Sequence Types — string, list, tuple, range.<br><br>
# There are two major categories: mutable and immutable types.<br>
# <b>Immutable</b> objects <b>cannot be changed</b>, while <b>Mutable</b> objects <b>can be changed</b>.<br>
# Integer, Floats, Strings, Tuples, Boolean are immutable.<br>
# List are mutable types.<br>
#
# https://docs.python.org/3/library/stdtypes.html
#
# https://media.geeksforgeeks.org/wp-content/uploads/20191023173512/Python-data-structure.jpg
#
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20191023173512/Python-data-structure.jpg" width="400">

# %% [markdown]
# ### Variables

# %% [markdown]
# Naming conventions
# * Underscore separated - variable_name - my preference
# * Camel case - VariableName
#
# There are many others:
# * https://en.wikipedia.org/wiki/Naming_convention_(programming)
#
# Use meaningful names, your future self will thank you!

# %% [markdown]
# <b>Assign</b> a value to a variable. <br>
# <b>The assignment operator is: "=" <br>

# %%
session_no = "6"

# %% [markdown]
# Check the value of a the variable session_no (just type the name of the variable in a cell)

# %%
session_no
# Out:
# '6'

# %% [markdown]
# <b>Calling a function: </b>
# * <b>use the function name and provide parameters in parentheses</b>
#
#
# ```python
# function_name(parameters)
# ```
#
#
# Example - use the print function to dispaly text:
# ```python
# print("This is a test")
# ```

# %% [markdown]
# Display the value of the variable session_no (use the print function)

# %%
print(session_no)
# Out:
# 6

# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
abs(-5)
# Out:
# 5

# %%
# ?abs
# Out:
# Signature: abs(x, /)
# Docstring: Return the absolute value of the argument.
# Type:      builtin_function_or_method

# %%
abs(5)
# Out:
# 5

# %%
# ?print
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
a = 3
b = 20
print(4,5,"there we are", a, b)
# Out:
# 4 5 there we are 3 20

# %% [markdown]
# Only the last variable in a cell will be displayed

# %%
a = 2
b = 5
print(a)
b
# Out:
# 2
# 5

# %%
a
b
# Out:
# 5

# %%
# Test more variables
a = 0
b = 1
text = "Here is a sequence 'AACGT'"

# %%
# %whos
# Out:
# Variable               Type             Data/Info
# -------------------------------------------------
# NamespaceMagics        MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# a                      int              0
# b                      int              1
# dataframe_columns      function         <function dataframe_columns at 0x135328400>
# dataframe_hash         function         <function dataframe_hash at 0x135328540>
# dtypes_str             function         <function dtypes_str at 0x135328220>
# get_dataframes         function         <function get_dataframes at 0x13532b920>
# get_ipython            function         <function get_ipython at 0x106f7d3a0>
# getpass                module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely   function         <function import_pandas_safely at 0x13532bb00>
# is_data_frame          function         <function is_data_frame at 0x135328720>
# json                   module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# my_module              module           <module 'my_module' from <...>data_types/my_module.py'>
# session_no             str              6
# sys                    module           <module 'sys' (built-in)>
# text                   str              Here is a sequence 'AACGT'
# this                   module           <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %%
a
# Out:
# 0

# %% [markdown]
# #### Check the variables you have in the environment
# ##### Use a magic command, only in notebooks
#    - <b> %whos </b>
#
# ##### Use a function:
#    - **globals()** - dictionary of the module namespace
#    - **locals()** -  dictionary of the current namespace
#    - **vars()** - a dictionary of the current namespace (if called with no argument) or the dictionary of the argument

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import this ',
#   "get_ipython().run_line_magic('who', '')",
#   'import my_module',
#   "get_ipython().run_line_magic('whos', '')",
#   'my_module.my_test_variable',
#   'my_module.my_test_variable = 7',
#   'my_module.my_test_variable',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'session_no = "6"',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'session_no',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'print(session_no)',
#   'dir(__builtin__)',
#   'abs(-5)',
#   "get_ipython().run_line_magic('pinfo', 'abs')",
#   'abs(5)',
#   "get_ipython().run_line_magic('pinfo', 'print')",
#   'a = 3\nb = 20\nprint(4,5,"there we are", a, b)',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'a = 2\nb = 5\nprint(a)\nb',
#   'a\nb',
#   '# Test more variables\na = 0\nb = 1\ntext = "Here is a sequence \'AACGT\'"',
#   "get_ipython().run_line_magic('whos', '')",
#   'a',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'globals()'],
#  '_oh': {1: '{"dataframes": [], "user": "mitrea"}',
#   2: '{"dataframes": [], "user": "mitrea"}',
#   3: '{"dataframes": [], "user": "mitrea"}',
#   4: '{"dataframes": [], "user": "mitrea"}',
#   5: '{"dataframes": [], "user": "mitrea"}',
#   6: '{"dataframes": [], "user": "mitrea"}',
#   7: '{"dataframes": [], "user": "mitrea"}',
#   8: '{"dataframes": [], "user": "mitrea"}',
#   9: '{"dataframes": [], "user": "mitrea"}',
#   10: '{"dataframes": [], "user": "mitrea"}',
#   11: '{"dataframes": [], "user": "mitrea"}',
#   12: '{"dataframes": [], "user": "mitrea"}',
#   13: '{"dataframes": [], "user": "mitrea"}',
#   14: '{"dataframes": [], "user": "mitrea"}',
#   19: 5,
#   21: 7,
#   22: '{"dataframes": [], "user": "mitrea"}',
#   23: '{"dataframes": [], "user": "mitrea"}',
#   24: '{"dataframes": [], "user": "mitrea"}',
#   25: '{"dataframes": [], "user": "mitrea"}',
#   27: '{"dataframes": [], "user": "mitrea"}',
#   28: '6',
#   29: '{"dataframes": [], "user": "mitrea"}',
#   30: '{"dataframes": [], "user": "mitrea"}',
#   32: ['ArithmeticError',
#    'AssertionError',
#    'AttributeError',
#    'BaseException',
#    'BaseExceptionGroup',
#    'BlockingIOError',
#    'BrokenPipeError',
#    'BufferError',
#    'BytesWarning',
#    'ChildProcessError',
#    'ConnectionAbortedError',
#    'ConnectionError',
#    'ConnectionRefusedError',
#    'ConnectionResetError',
#    'DeprecationWarning',
#    'EOFError',
#    'Ellipsis',
#    'EncodingWarning',
#    'EnvironmentError',
#    'Exception',
#    'ExceptionGroup',
#    'False',
#    'FileExistsError',
#    'FileNotFoundError',
#    'FloatingPointError',
#    'FutureWarning',
#    'GeneratorExit',
#    'IOError',
#    'ImportError',
#    'ImportWarning',
#    'IndentationError',
#    'IndexError',
#    'InterruptedError',
#    'IsADirectoryError',
#    'KeyError',
#    'KeyboardInterrupt',
#    'LookupError',
#    'MemoryError',
#    'ModuleNotFoundError',
#    'NameError',
#    'None',
#    'NotADirectoryError',
#    'NotImplemented',
#    'NotImplementedError',
#    'OSError',
#    'OverflowError',
#    'PendingDeprecationWarning',
#    'PermissionError',
#    'ProcessLookupError',
#    'RecursionError',
#    'ReferenceError',
#    'ResourceWarning',
#    'RuntimeError',
#    'RuntimeWarning',
#    'StopAsyncIteration',
#    'StopIteration',
#    'SyntaxError',
#    'SyntaxWarning',
#    'SystemError',
#    'SystemExit',
#    'TabError',
#    'TimeoutError',
#    'True',
#    'TypeError',
#    'UnboundLocalError',
#    'UnicodeDecodeError',
#    'UnicodeEncodeError',
#    'UnicodeError',
#    'UnicodeTranslateError',
#    'UnicodeWarning',
#    'UserWarning',
#    'ValueError',
#    'Warning',
#    'ZeroDivisionError',
#    '__IPYTHON__',
#    '__build_class__',
#    '__debug__',
#    '__doc__',
#    '__import__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    'abs',
#    'aiter',
#    'all',
#    'anext',
#    'any',
#    'ascii',
#    'bin',
#    'bool',
#    'breakpoint',
#    'bytearray',
#    'bytes',
#    'callable',
#    'chr',
#    'classmethod',
#    'compile',
#    'complex',
#    'copyright',
#    'credits',
#    'delattr',
#    'dict',
#    'dir',
#    'display',
#    'divmod',
#    'enumerate',
#    'eval',
#    'exec',
#    'execfile',
#    'filter',
#    'float',
#    'format',
#    'frozenset',
#    'get_ipython',
#    'getattr',
#    'globals',
#    'hasattr',
#    'hash',
#    'help',
#    'hex',
#    'id',
#    'input',
#    'int',
#    'isinstance',
#    'issubclass',
#    'iter',
#    'len',
#    'license',
#    'list',
#    'locals',
#    'map',
#    'max',
#    'memoryview',
#    'min',
#    'next',
#    'object',
#    'oct',
#    'open',
#    'ord',
#    'pow',
#    'print',
#    'property',
#    'range',
#    'repr',
#    'reversed',
#    'round',
#    'runfile',
#    'set',
#    'setattr',
#    'slice',
#    'sorted',
#    'staticmethod',
#    'str',
#    'sum',
#    'super',
#    'tuple',
#    'type',
#    'vars',
#    'zip'],
#   33: 5,
#   35: 5,
#   38: '{"dataframes": [], "user": "mitrea"}',
#   39: 5,
#   40: 5,
#   43: 0,
#   44: '{"dataframes": [], "user": "mitrea"}'},
#  '_dh': [PosixPath('/Users/mitrea/Documents/academic_docs/CLASSES/FALL_2025/BIOINF 575 FA 2025/bioinf575/class_sessions/session6_data_types')],
#  'In': ['',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
# ...
#  '_23': '{"dataframes": [], "user": "mitrea"}',
#  '_i24': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_24': '{"dataframes": [], "user": "mitrea"}',
#  '_i25': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_25': '{"dataframes": [], "user": "mitrea"}',
#  '_i26': 'session_no = "6"',
#  'session_no': '6',
#  '_i27': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_27': '{"dataframes": [], "user": "mitrea"}',
#  '_i28': 'session_no',
#  '_28': '6',
#  '_i29': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_29': '{"dataframes": [], "user": "mitrea"}',
#  '_i30': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_30': '{"dataframes": [], "user": "mitrea"}',
#  '_i31': 'print(session_no)',
#  '_i32': 'dir(__builtin__)',
#  '_32': ['ArithmeticError',
#   'AssertionError',
#   'AttributeError',
#   'BaseException',
#   'BaseExceptionGroup',
#   'BlockingIOError',
#   'BrokenPipeError',
#   'BufferError',
#   'BytesWarning',
#   'ChildProcessError',
#   'ConnectionAbortedError',
#   'ConnectionError',
#   'ConnectionRefusedError',
#   'ConnectionResetError',
#   'DeprecationWarning',
#   'EOFError',
#   'Ellipsis',
#   'EncodingWarning',
#   'EnvironmentError',
#   'Exception',
#   'ExceptionGroup',
#   'False',
#   'FileExistsError',
#   'FileNotFoundError',
#   'FloatingPointError',
#   'FutureWarning',
#   'GeneratorExit',
#   'IOError',
#   'ImportError',
#   'ImportWarning',
#   'IndentationError',
#   'IndexError',
#   'InterruptedError',
#   'IsADirectoryError',
#   'KeyError',
#   'KeyboardInterrupt',
#   'LookupError',
#   'MemoryError',
#   'ModuleNotFoundError',
#   'NameError',
#   'None',
#   'NotADirectoryError',
#   'NotImplemented',
#   'NotImplementedError',
#   'OSError',
#   'OverflowError',
#   'PendingDeprecationWarning',
#   'PermissionError',
#   'ProcessLookupError',
#   'RecursionError',
#   'ReferenceError',
#   'ResourceWarning',
#   'RuntimeError',
#   'RuntimeWarning',
#   'StopAsyncIteration',
#   'StopIteration',
#   'SyntaxError',
#   'SyntaxWarning',
#   'SystemError',
#   'SystemExit',
#   'TabError',
#   'TimeoutError',
#   'True',
#   'TypeError',
#   'UnboundLocalError',
#   'UnicodeDecodeError',
#   'UnicodeEncodeError',
#   'UnicodeError',
#   'UnicodeTranslateError',
#   'UnicodeWarning',
#   'UserWarning',
#   'ValueError',
#   'Warning',
#   'ZeroDivisionError',
#   '__IPYTHON__',
#   '__build_class__',
#   '__debug__',
#   '__doc__',
#   '__import__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   'abs',
#   'aiter',
#   'all',
#   'anext',
#   'any',
#   'ascii',
#   'bin',
#   'bool',
#   'breakpoint',
#   'bytearray',
#   'bytes',
#   'callable',
#   'chr',
#   'classmethod',
#   'compile',
#   'complex',
#   'copyright',
#   'credits',
#   'delattr',
#   'dict',
#   'dir',
#   'display',
#   'divmod',
#   'enumerate',
#   'eval',
#   'exec',
#   'execfile',
#   'filter',
#   'float',
#   'format',
#   'frozenset',
#   'get_ipython',
#   'getattr',
#   'globals',
#   'hasattr',
#   'hash',
#   'help',
#   'hex',
#   'id',
#   'input',
#   'int',
#   'isinstance',
#   'issubclass',
#   'iter',
#   'len',
#   'license',
#   'list',
#   'locals',
#   'map',
#   'max',
#   'memoryview',
#   'min',
#   'next',
#   'object',
#   'oct',
#   'open',
#   'ord',
#   'pow',
#   'print',
#   'property',
#   'range',
#   'repr',
#   'reversed',
#   'round',
#   'runfile',
#   'set',
#   'setattr',
#   'slice',
#   'sorted',
#   'staticmethod',
#   'str',
#   'sum',
#   'super',
#   'tuple',
#   'type',
#   'vars',
#   'zip'],
#  '_i33': 'abs(-5)',
#  '_33': 5,
#  '_i34': '?abs',
#  '_i35': 'abs(5)',
#  '_35': 5,
#  '_i36': '?print',
#  '_i37': 'a = 3\nb = 20\nprint(4,5,"there we are", a, b)',
#  'a': 0,
#  'b': 1,
#  '_i38': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_38': '{"dataframes": [], "user": "mitrea"}',
#  '_i39': 'a = 2\nb = 5\nprint(a)\nb',
#  '_39': 5,
#  '_i40': 'a\nb',
#  '_40': 5,
#  '_i41': '# Test more variables\na = 0\nb = 1\ntext = "Here is a sequence \'AACGT\'"',
#  'text': "Here is a sequence 'AACGT'",
#  '_i42': '%whos',
#  '_i43': 'a',
#  '_43': 0,
#  '_i44': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_44': '{"dataframes": [], "user": "mitrea"}',
#  '_i45': 'globals()'}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import this ',
#   "get_ipython().run_line_magic('who', '')",
#   'import my_module',
#   "get_ipython().run_line_magic('whos', '')",
#   'my_module.my_test_variable',
#   'my_module.my_test_variable = 7',
#   'my_module.my_test_variable',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'session_no = "6"',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'session_no',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'print(session_no)',
#   'dir(__builtin__)',
#   'abs(-5)',
#   "get_ipython().run_line_magic('pinfo', 'abs')",
#   'abs(5)',
#   "get_ipython().run_line_magic('pinfo', 'print')",
#   'a = 3\nb = 20\nprint(4,5,"there we are", a, b)',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'a = 2\nb = 5\nprint(a)\nb',
#   'a\nb',
#   '# Test more variables\na = 0\nb = 1\ntext = "Here is a sequence \'AACGT\'"',
#   "get_ipython().run_line_magic('whos', '')",
#   'a',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'globals()',
#   'locals()'],
#  '_oh': {1: '{"dataframes": [], "user": "mitrea"}',
#   2: '{"dataframes": [], "user": "mitrea"}',
#   3: '{"dataframes": [], "user": "mitrea"}',
#   4: '{"dataframes": [], "user": "mitrea"}',
#   5: '{"dataframes": [], "user": "mitrea"}',
#   6: '{"dataframes": [], "user": "mitrea"}',
#   7: '{"dataframes": [], "user": "mitrea"}',
#   8: '{"dataframes": [], "user": "mitrea"}',
#   9: '{"dataframes": [], "user": "mitrea"}',
#   10: '{"dataframes": [], "user": "mitrea"}',
#   11: '{"dataframes": [], "user": "mitrea"}',
#   12: '{"dataframes": [], "user": "mitrea"}',
#   13: '{"dataframes": [], "user": "mitrea"}',
#   14: '{"dataframes": [], "user": "mitrea"}',
#   19: 5,
#   21: 7,
#   22: '{"dataframes": [], "user": "mitrea"}',
#   23: '{"dataframes": [], "user": "mitrea"}',
#   24: '{"dataframes": [], "user": "mitrea"}',
#   25: '{"dataframes": [], "user": "mitrea"}',
#   27: '{"dataframes": [], "user": "mitrea"}',
#   28: '6',
#   29: '{"dataframes": [], "user": "mitrea"}',
#   30: '{"dataframes": [], "user": "mitrea"}',
#   32: ['ArithmeticError',
#    'AssertionError',
#    'AttributeError',
#    'BaseException',
#    'BaseExceptionGroup',
#    'BlockingIOError',
#    'BrokenPipeError',
#    'BufferError',
#    'BytesWarning',
#    'ChildProcessError',
#    'ConnectionAbortedError',
#    'ConnectionError',
#    'ConnectionRefusedError',
#    'ConnectionResetError',
#    'DeprecationWarning',
#    'EOFError',
#    'Ellipsis',
#    'EncodingWarning',
#    'EnvironmentError',
#    'Exception',
#    'ExceptionGroup',
#    'False',
#    'FileExistsError',
#    'FileNotFoundError',
#    'FloatingPointError',
#    'FutureWarning',
#    'GeneratorExit',
#    'IOError',
#    'ImportError',
#    'ImportWarning',
#    'IndentationError',
#    'IndexError',
#    'InterruptedError',
#    'IsADirectoryError',
#    'KeyError',
#    'KeyboardInterrupt',
#    'LookupError',
#    'MemoryError',
#    'ModuleNotFoundError',
#    'NameError',
#    'None',
#    'NotADirectoryError',
#    'NotImplemented',
#    'NotImplementedError',
#    'OSError',
#    'OverflowError',
#    'PendingDeprecationWarning',
#    'PermissionError',
#    'ProcessLookupError',
#    'RecursionError',
#    'ReferenceError',
#    'ResourceWarning',
#    'RuntimeError',
#    'RuntimeWarning',
#    'StopAsyncIteration',
#    'StopIteration',
#    'SyntaxError',
#    'SyntaxWarning',
#    'SystemError',
#    'SystemExit',
#    'TabError',
#    'TimeoutError',
#    'True',
#    'TypeError',
#    'UnboundLocalError',
#    'UnicodeDecodeError',
#    'UnicodeEncodeError',
#    'UnicodeError',
#    'UnicodeTranslateError',
#    'UnicodeWarning',
#    'UserWarning',
#    'ValueError',
#    'Warning',
#    'ZeroDivisionError',
#    '__IPYTHON__',
#    '__build_class__',
#    '__debug__',
#    '__doc__',
#    '__import__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    'abs',
#    'aiter',
#    'all',
#    'anext',
#    'any',
#    'ascii',
#    'bin',
#    'bool',
#    'breakpoint',
#    'bytearray',
#    'bytes',
#    'callable',
#    'chr',
#    'classmethod',
#    'compile',
#    'complex',
#    'copyright',
#    'credits',
#    'delattr',
#    'dict',
#    'dir',
#    'display',
#    'divmod',
#    'enumerate',
#    'eval',
#    'exec',
#    'execfile',
#    'filter',
#    'float',
#    'format',
#    'frozenset',
#    'get_ipython',
#    'getattr',
#    'globals',
#    'hasattr',
#    'hash',
#    'help',
#    'hex',
#    'id',
#    'input',
#    'int',
#    'isinstance',
#    'issubclass',
#    'iter',
#    'len',
#    'license',
#    'list',
#    'locals',
#    'map',
#    'max',
#    'memoryview',
#    'min',
#    'next',
#    'object',
#    'oct',
#    'open',
#    'ord',
#    'pow',
#    'print',
#    'property',
#    'range',
#    'repr',
#    'reversed',
#    'round',
#    'runfile',
#    'set',
#    'setattr',
#    'slice',
#    'sorted',
#    'staticmethod',
#    'str',
#    'sum',
#    'super',
#    'tuple',
#    'type',
#    'vars',
#    'zip'],
#   33: 5,
#   35: 5,
#   38: '{"dataframes": [], "user": "mitrea"}',
#   39: 5,
#   40: 5,
#   43: 0,
#   44: '{"dataframes": [], "user": "mitrea"}',
#   45: {...}},
#  '_dh': [PosixPath('/Users/mitrea/Documents/academic_docs/CLASSES/FALL_2025/BIOINF 575 FA 2025/bioinf575/class_sessions/session6_data_types')],
#  'In': ['',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
# ...
#  '_23': '{"dataframes": [], "user": "mitrea"}',
#  '_i24': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_24': '{"dataframes": [], "user": "mitrea"}',
#  '_i25': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_25': '{"dataframes": [], "user": "mitrea"}',
#  '_i26': 'session_no = "6"',
#  'session_no': '6',
#  '_i27': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_27': '{"dataframes": [], "user": "mitrea"}',
#  '_i28': 'session_no',
#  '_28': '6',
#  '_i29': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_29': '{"dataframes": [], "user": "mitrea"}',
#  '_i30': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_30': '{"dataframes": [], "user": "mitrea"}',
#  '_i31': 'print(session_no)',
#  '_i32': 'dir(__builtin__)',
#  '_32': ['ArithmeticError',
#   'AssertionError',
#   'AttributeError',
#   'BaseException',
#   'BaseExceptionGroup',
#   'BlockingIOError',
#   'BrokenPipeError',
#   'BufferError',
#   'BytesWarning',
#   'ChildProcessError',
#   'ConnectionAbortedError',
#   'ConnectionError',
#   'ConnectionRefusedError',
#   'ConnectionResetError',
#   'DeprecationWarning',
#   'EOFError',
#   'Ellipsis',
#   'EncodingWarning',
#   'EnvironmentError',
#   'Exception',
#   'ExceptionGroup',
#   'False',
#   'FileExistsError',
#   'FileNotFoundError',
#   'FloatingPointError',
#   'FutureWarning',
#   'GeneratorExit',
#   'IOError',
#   'ImportError',
#   'ImportWarning',
#   'IndentationError',
#   'IndexError',
#   'InterruptedError',
#   'IsADirectoryError',
#   'KeyError',
#   'KeyboardInterrupt',
#   'LookupError',
#   'MemoryError',
#   'ModuleNotFoundError',
#   'NameError',
#   'None',
#   'NotADirectoryError',
#   'NotImplemented',
#   'NotImplementedError',
#   'OSError',
#   'OverflowError',
#   'PendingDeprecationWarning',
#   'PermissionError',
#   'ProcessLookupError',
#   'RecursionError',
#   'ReferenceError',
#   'ResourceWarning',
#   'RuntimeError',
#   'RuntimeWarning',
#   'StopAsyncIteration',
#   'StopIteration',
#   'SyntaxError',
#   'SyntaxWarning',
#   'SystemError',
#   'SystemExit',
#   'TabError',
#   'TimeoutError',
#   'True',
#   'TypeError',
#   'UnboundLocalError',
#   'UnicodeDecodeError',
#   'UnicodeEncodeError',
#   'UnicodeError',
#   'UnicodeTranslateError',
#   'UnicodeWarning',
#   'UserWarning',
#   'ValueError',
#   'Warning',
#   'ZeroDivisionError',
#   '__IPYTHON__',
#   '__build_class__',
#   '__debug__',
#   '__doc__',
#   '__import__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   'abs',
#   'aiter',
#   'all',
#   'anext',
#   'any',
#   'ascii',
#   'bin',
#   'bool',
#   'breakpoint',
#   'bytearray',
#   'bytes',
#   'callable',
#   'chr',
#   'classmethod',
#   'compile',
#   'complex',
#   'copyright',
#   'credits',
#   'delattr',
#   'dict',
#   'dir',
#   'display',
#   'divmod',
#   'enumerate',
#   'eval',
#   'exec',
#   'execfile',
#   'filter',
#   'float',
#   'format',
#   'frozenset',
#   'get_ipython',
#   'getattr',
#   'globals',
#   'hasattr',
#   'hash',
#   'help',
#   'hex',
#   'id',
#   'input',
#   'int',
#   'isinstance',
#   'issubclass',
#   'iter',
#   'len',
#   'license',
#   'list',
#   'locals',
#   'map',
#   'max',
#   'memoryview',
#   'min',
#   'next',
#   'object',
#   'oct',
#   'open',
#   'ord',
#   'pow',
#   'print',
#   'property',
#   'range',
#   'repr',
#   'reversed',
#   'round',
#   'runfile',
#   'set',
#   'setattr',
#   'slice',
#   'sorted',
#   'staticmethod',
#   'str',
#   'sum',
#   'super',
#   'tuple',
#   'type',
#   'vars',
#   'zip'],
#  '_i33': 'abs(-5)',
#  '_33': 5,
#  '_i34': '?abs',
#  '_i35': 'abs(5)',
#  '_35': 5,
#  '_i36': '?print',
#  '_i37': 'a = 3\nb = 20\nprint(4,5,"there we are", a, b)',
#  'a': 0,
#  'b': 1,
#  '_i38': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_38': '{"dataframes": [], "user": "mitrea"}',
#  '_i39': 'a = 2\nb = 5\nprint(a)\nb',
#  '_39': 5,
#  '_i40': 'a\nb',
#  '_40': 5,
#  '_i41': '# Test more variables\na = 0\nb = 1\ntext = "Here is a sequence \'AACGT\'"',
#  'text': "Here is a sequence 'AACGT'",
#  '_i42': '%whos',
#  '_i43': 'a',
#  '_43': 0,
#  '_i44': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_44': '{"dataframes": [], "user": "mitrea"}',
#  '_i45': 'globals()',
#  '_45': {...},
#  '_i46': 'locals()'}

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import this ',
#   "get_ipython().run_line_magic('who', '')",
#   'import my_module',
#   "get_ipython().run_line_magic('whos', '')",
#   'my_module.my_test_variable',
#   'my_module.my_test_variable = 7',
#   'my_module.my_test_variable',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'session_no = "6"',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'session_no',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'print(session_no)',
#   'dir(__builtin__)',
#   'abs(-5)',
#   "get_ipython().run_line_magic('pinfo', 'abs')",
#   'abs(5)',
#   "get_ipython().run_line_magic('pinfo', 'print')",
#   'a = 3\nb = 20\nprint(4,5,"there we are", a, b)',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'a = 2\nb = 5\nprint(a)\nb',
#   'a\nb',
#   '# Test more variables\na = 0\nb = 1\ntext = "Here is a sequence \'AACGT\'"',
#   "get_ipython().run_line_magic('whos', '')",
#   'a',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'globals()',
#   'locals()',
#   'vars()'],
#  '_oh': {1: '{"dataframes": [], "user": "mitrea"}',
#   2: '{"dataframes": [], "user": "mitrea"}',
#   3: '{"dataframes": [], "user": "mitrea"}',
#   4: '{"dataframes": [], "user": "mitrea"}',
#   5: '{"dataframes": [], "user": "mitrea"}',
#   6: '{"dataframes": [], "user": "mitrea"}',
#   7: '{"dataframes": [], "user": "mitrea"}',
#   8: '{"dataframes": [], "user": "mitrea"}',
#   9: '{"dataframes": [], "user": "mitrea"}',
#   10: '{"dataframes": [], "user": "mitrea"}',
#   11: '{"dataframes": [], "user": "mitrea"}',
#   12: '{"dataframes": [], "user": "mitrea"}',
#   13: '{"dataframes": [], "user": "mitrea"}',
#   14: '{"dataframes": [], "user": "mitrea"}',
#   19: 5,
#   21: 7,
#   22: '{"dataframes": [], "user": "mitrea"}',
#   23: '{"dataframes": [], "user": "mitrea"}',
#   24: '{"dataframes": [], "user": "mitrea"}',
#   25: '{"dataframes": [], "user": "mitrea"}',
#   27: '{"dataframes": [], "user": "mitrea"}',
#   28: '6',
#   29: '{"dataframes": [], "user": "mitrea"}',
#   30: '{"dataframes": [], "user": "mitrea"}',
#   32: ['ArithmeticError',
#    'AssertionError',
#    'AttributeError',
#    'BaseException',
#    'BaseExceptionGroup',
#    'BlockingIOError',
#    'BrokenPipeError',
#    'BufferError',
#    'BytesWarning',
#    'ChildProcessError',
#    'ConnectionAbortedError',
#    'ConnectionError',
#    'ConnectionRefusedError',
#    'ConnectionResetError',
#    'DeprecationWarning',
#    'EOFError',
#    'Ellipsis',
#    'EncodingWarning',
#    'EnvironmentError',
#    'Exception',
#    'ExceptionGroup',
#    'False',
#    'FileExistsError',
#    'FileNotFoundError',
#    'FloatingPointError',
#    'FutureWarning',
#    'GeneratorExit',
#    'IOError',
#    'ImportError',
#    'ImportWarning',
#    'IndentationError',
#    'IndexError',
#    'InterruptedError',
#    'IsADirectoryError',
#    'KeyError',
#    'KeyboardInterrupt',
#    'LookupError',
#    'MemoryError',
#    'ModuleNotFoundError',
#    'NameError',
#    'None',
#    'NotADirectoryError',
#    'NotImplemented',
#    'NotImplementedError',
#    'OSError',
#    'OverflowError',
#    'PendingDeprecationWarning',
#    'PermissionError',
#    'ProcessLookupError',
#    'RecursionError',
#    'ReferenceError',
#    'ResourceWarning',
#    'RuntimeError',
#    'RuntimeWarning',
#    'StopAsyncIteration',
#    'StopIteration',
#    'SyntaxError',
#    'SyntaxWarning',
#    'SystemError',
#    'SystemExit',
#    'TabError',
#    'TimeoutError',
#    'True',
#    'TypeError',
#    'UnboundLocalError',
#    'UnicodeDecodeError',
#    'UnicodeEncodeError',
#    'UnicodeError',
#    'UnicodeTranslateError',
#    'UnicodeWarning',
#    'UserWarning',
#    'ValueError',
#    'Warning',
#    'ZeroDivisionError',
#    '__IPYTHON__',
#    '__build_class__',
#    '__debug__',
#    '__doc__',
#    '__import__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    'abs',
#    'aiter',
#    'all',
#    'anext',
#    'any',
#    'ascii',
#    'bin',
#    'bool',
#    'breakpoint',
#    'bytearray',
#    'bytes',
#    'callable',
#    'chr',
#    'classmethod',
#    'compile',
#    'complex',
#    'copyright',
#    'credits',
#    'delattr',
#    'dict',
#    'dir',
#    'display',
#    'divmod',
#    'enumerate',
#    'eval',
#    'exec',
#    'execfile',
#    'filter',
#    'float',
#    'format',
#    'frozenset',
#    'get_ipython',
#    'getattr',
#    'globals',
#    'hasattr',
#    'hash',
#    'help',
#    'hex',
#    'id',
#    'input',
#    'int',
#    'isinstance',
#    'issubclass',
#    'iter',
#    'len',
#    'license',
#    'list',
#    'locals',
#    'map',
#    'max',
#    'memoryview',
#    'min',
#    'next',
#    'object',
#    'oct',
#    'open',
#    'ord',
#    'pow',
#    'print',
#    'property',
#    'range',
#    'repr',
#    'reversed',
#    'round',
#    'runfile',
#    'set',
#    'setattr',
#    'slice',
#    'sorted',
#    'staticmethod',
#    'str',
#    'sum',
#    'super',
#    'tuple',
#    'type',
#    'vars',
#    'zip'],
#   33: 5,
#   35: 5,
#   38: '{"dataframes": [], "user": "mitrea"}',
#   39: 5,
#   40: 5,
#   43: 0,
#   44: '{"dataframes": [], "user": "mitrea"}',
#   45: {...},
#   46: {...}},
#  '_dh': [PosixPath('/Users/mitrea/Documents/academic_docs/CLASSES/FALL_2025/BIOINF 575 FA 2025/bioinf575/class_sessions/session6_data_types')],
#  'In': ['',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#   'import json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = get_ipython().run_line_magic(\'who_ls\', \'\')\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
# ...
#  '_23': '{"dataframes": [], "user": "mitrea"}',
#  '_i24': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_24': '{"dataframes": [], "user": "mitrea"}',
#  '_i25': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_25': '{"dataframes": [], "user": "mitrea"}',
#  '_i26': 'session_no = "6"',
#  'session_no': '6',
#  '_i27': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_27': '{"dataframes": [], "user": "mitrea"}',
#  '_i28': 'session_no',
#  '_28': '6',
#  '_i29': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_29': '{"dataframes": [], "user": "mitrea"}',
#  '_i30': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_30': '{"dataframes": [], "user": "mitrea"}',
#  '_i31': 'print(session_no)',
#  '_i32': 'dir(__builtin__)',
#  '_32': ['ArithmeticError',
#   'AssertionError',
#   'AttributeError',
#   'BaseException',
#   'BaseExceptionGroup',
#   'BlockingIOError',
#   'BrokenPipeError',
#   'BufferError',
#   'BytesWarning',
#   'ChildProcessError',
#   'ConnectionAbortedError',
#   'ConnectionError',
#   'ConnectionRefusedError',
#   'ConnectionResetError',
#   'DeprecationWarning',
#   'EOFError',
#   'Ellipsis',
#   'EncodingWarning',
#   'EnvironmentError',
#   'Exception',
#   'ExceptionGroup',
#   'False',
#   'FileExistsError',
#   'FileNotFoundError',
#   'FloatingPointError',
#   'FutureWarning',
#   'GeneratorExit',
#   'IOError',
#   'ImportError',
#   'ImportWarning',
#   'IndentationError',
#   'IndexError',
#   'InterruptedError',
#   'IsADirectoryError',
#   'KeyError',
#   'KeyboardInterrupt',
#   'LookupError',
#   'MemoryError',
#   'ModuleNotFoundError',
#   'NameError',
#   'None',
#   'NotADirectoryError',
#   'NotImplemented',
#   'NotImplementedError',
#   'OSError',
#   'OverflowError',
#   'PendingDeprecationWarning',
#   'PermissionError',
#   'ProcessLookupError',
#   'RecursionError',
#   'ReferenceError',
#   'ResourceWarning',
#   'RuntimeError',
#   'RuntimeWarning',
#   'StopAsyncIteration',
#   'StopIteration',
#   'SyntaxError',
#   'SyntaxWarning',
#   'SystemError',
#   'SystemExit',
#   'TabError',
#   'TimeoutError',
#   'True',
#   'TypeError',
#   'UnboundLocalError',
#   'UnicodeDecodeError',
#   'UnicodeEncodeError',
#   'UnicodeError',
#   'UnicodeTranslateError',
#   'UnicodeWarning',
#   'UserWarning',
#   'ValueError',
#   'Warning',
#   'ZeroDivisionError',
#   '__IPYTHON__',
#   '__build_class__',
#   '__debug__',
#   '__doc__',
#   '__import__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   'abs',
#   'aiter',
#   'all',
#   'anext',
#   'any',
#   'ascii',
#   'bin',
#   'bool',
#   'breakpoint',
#   'bytearray',
#   'bytes',
#   'callable',
#   'chr',
#   'classmethod',
#   'compile',
#   'complex',
#   'copyright',
#   'credits',
#   'delattr',
#   'dict',
#   'dir',
#   'display',
#   'divmod',
#   'enumerate',
#   'eval',
#   'exec',
#   'execfile',
#   'filter',
#   'float',
#   'format',
#   'frozenset',
#   'get_ipython',
#   'getattr',
#   'globals',
#   'hasattr',
#   'hash',
#   'help',
#   'hex',
#   'id',
#   'input',
#   'int',
#   'isinstance',
#   'issubclass',
#   'iter',
#   'len',
#   'license',
#   'list',
#   'locals',
#   'map',
#   'max',
#   'memoryview',
#   'min',
#   'next',
#   'object',
#   'oct',
#   'open',
#   'ord',
#   'pow',
#   'print',
#   'property',
#   'range',
#   'repr',
#   'reversed',
#   'round',
#   'runfile',
#   'set',
#   'setattr',
#   'slice',
#   'sorted',
#   'staticmethod',
#   'str',
#   'sum',
#   'super',
#   'tuple',
#   'type',
#   'vars',
#   'zip'],
#  '_i33': 'abs(-5)',
#  '_33': 5,
#  '_i34': '?abs',
#  '_i35': 'abs(5)',
#  '_35': 5,
#  '_i36': '?print',
#  '_i37': 'a = 3\nb = 20\nprint(4,5,"there we are", a, b)',
#  'a': 0,
#  'b': 1,
#  '_i38': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_38': '{"dataframes": [], "user": "mitrea"}',
#  '_i39': 'a = 2\nb = 5\nprint(a)\nb',
#  '_39': 5,
#  '_i40': 'a\nb',
#  '_40': 5,
#  '_i41': '# Test more variables\na = 0\nb = 1\ntext = "Here is a sequence \'AACGT\'"',
#  'text': "Here is a sequence 'AACGT'",
#  '_i42': '%whos',
#  '_i43': 'a',
#  '_43': 0,
#  '_i44': '\nimport json\nimport getpass\nimport hashlib\n\ndef import_pandas_safely():\n    try:\n        return __import__(\'pandas\')\n    except ImportError:\n        return False\n\n\n__pandas = import_pandas_safely()\n\n\ndef is_data_frame(v: str):\n    obj = eval(v)\n    if  isinstance(obj, __pandas.core.frame.DataFrame) or isinstance(obj, __pandas.core.series.Series):\n        return True\n\n\ndef dataframe_columns(var):\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return [[df.name, str(df.dtype)]]\n    return list(map(lambda col: [col, str(df[col].dtype)], df.columns))\n\n\ndef dtypes_str(frame):\n    return str(eval(frame).dtypes)\n\ndef dataframe_hash(var):\n    # Return a hash including the column names and number of rows\n    df = eval(var)\n    if isinstance(df, __pandas.core.series.Series):\n        return hashlib.sha256(f"{var}-{df.name},{len(df)}".encode(\'utf-8\')).hexdigest()\n    return hashlib.sha256(f"{var}-{\',\'.join(df.columns)},{len(df)}".encode(\'utf-8\')).hexdigest()\n\ndef get_dataframes():\n    if __pandas is None:\n        return []\n    user = getpass.getuser()\n    values = %who_ls\n    dataframes = [\n        {\n            "name": var,\n            "type": type(eval(var)).__name__,\n            "hash": dataframe_hash(var),\n            "cols": dataframe_columns(var),\n            "dtypesStr": dtypes_str(var),\n        }\n        for var in values if is_data_frame(var)\n    ]\n    result = {"dataframes": dataframes, "user": user}\n    return json.dumps(result, ensure_ascii=False)\n\n\nget_dataframes()',
#  '_44': '{"dataframes": [], "user": "mitrea"}',
#  '_i45': 'globals()',
#  '_45': {...},
#  '_i46': 'locals()',
#  '_46': {...},
#  '_i47': 'vars()'}

# %%
# %whos
# Out:
# Variable               Type             Data/Info
# -------------------------------------------------
# NamespaceMagics        MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# a                      int              0
# b                      int              1
# dataframe_columns      function         <function dataframe_columns at 0x135328720>
# dataframe_hash         function         <function dataframe_hash at 0x135328220>
# dtypes_str             function         <function dtypes_str at 0x135328400>
# get_dataframes         function         <function get_dataframes at 0x135328540>
# get_ipython            function         <function get_ipython at 0x106f7d3a0>
# getpass                module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely   function         <function import_pandas_safely at 0x13537ce00>
# is_data_frame          function         <function is_data_frame at 0x13537cc20>
# json                   module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# my_module              module           <module 'my_module' from <...>data_types/my_module.py'>
# session_no             str              6
# sys                    module           <module 'sys' (built-in)>
# text                   str              Here is a sequence 'AACGT'
# this                   module           <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %%
# using the result of the vars() function 
# - but it includes extra variables so we use a comprehension 
# to return the results and filter those out

[v for v in vars().items() 
 if (not v[0].startswith('_')) & 
 (v[0] not in ["In", "Out", "exit", "quit", "get_ipython"])]
# Out:
# [('open',
#   <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>),
#  ('json',
#   <module 'json' from '/opt/anaconda3/lib/python3.12/json/__init__.py'>),
#  ('sys', <module 'sys' (built-in)>),
#  ('NamespaceMagics', IPython.core.magics.namespace.NamespaceMagics),
#  ('getpass',
#   <module 'getpass' from '/opt/anaconda3/lib/python3.12/getpass.py'>),
#  ('hashlib',
#   <module 'hashlib' from '/opt/anaconda3/lib/python3.12/hashlib.py'>),
#  ('import_pandas_safely', <function __main__.import_pandas_safely()>),
#  ('is_data_frame', <function __main__.is_data_frame(v: str)>),
#  ('dataframe_columns', <function __main__.dataframe_columns(var)>),
#  ('dtypes_str', <function __main__.dtypes_str(frame)>),
#  ('dataframe_hash', <function __main__.dataframe_hash(var)>),
#  ('get_dataframes', <function __main__.get_dataframes()>),
#  ('this', <module 'this' from '/opt/anaconda3/lib/python3.12/this.py'>),
#  ('my_module',
#   <module 'my_module' from '/Users/mitrea/Documents/academic_docs/CLASSES/FALL_2025/BIOINF 575 FA 2025/bioinf575/class_sessions/session6_data_types/my_module.py'>),
#  ('session_no', '6'),
#  ('a', 0),
#  ('b', 1),
#  ('text', "Here is a sequence 'AACGT'")]

# %% [markdown]
# ##### Check the type of the data - use the function <b> type()

# %%
type(4.0)
# Out:
# float

# %%
type("ABC")
# Out:
# str

# %%
type([1,2,3])
# Out:
# list

# %%
type(0)
# Out:
# int

# %%
type(234)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(a)
# Out:
# int

# %%
a
# Out:
# 0

# %% [markdown]
# <font color = "red">EXERCISE</font> <br>
# <br>
# Assign the value 10 to the variable apples_count.<br>
# Assign the value 234.6 to the variable savings.<br><br>
# Assign the value 100 to the variable attendance_percentage.<br>
# Assign the value of the variable attendance_percentage to the variable quiz_percentage.<br><br>
# <b>Multiple assignment:</b> assign the value 20 to two variables (no1 and no2) at the same time, in one line.<br>
# Then check the value of the two variables.<br><br>

# %%
### Write your solution in the following cells
apples_count = 10
attendance_percentage = 100
quiz_percentage = 2 * attendance_percentage
no1=no2=20
print(no1,no2)
# Out:
# 20 20

# %%
print(apples_count, attendance_percentage, quiz_percentage, no1, no2)
# Out:
# 10 100 200 20 20

# %%
print("apples_count is:", apples_count, attendance_percentage, quiz_percentage, no1, no2)
# Out:
# apples_count is: 10 100 200 20 20

# %%
apples_count = 10
apples_count
# Out:
# 10

# %%
attendance_percentage
# Out:
# 100

# %% [markdown]
# <b>Remove the value from the variable message using the assignment of the value <b>None</b>.

# %%
# check its value first
session_no
# Out:
# '6'

# %%
message = "We are testing del"

# %%
message
# Out:
# 'We are testing del'

# %%
# %whos
# Out:
# Variable                Type             Data/Info
# --------------------------------------------------
# NamespaceMagics         MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# a                       int              0
# apples_count            int              10
# attendance_percentage   int              100
# b                       int              1
# dataframe_columns       function         <function dataframe_columns at 0x1353460c0>
# dataframe_hash          function         <function dataframe_hash at 0x1353465c0>
# dtypes_str              function         <function dtypes_str at 0x135346660>
# get_dataframes          function         <function get_dataframes at 0x135344d60>
# get_ipython             function         <function get_ipython at 0x106f7d3a0>
# getpass                 module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                 module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely    function         <function import_pandas_safely at 0x1353442c0>
# is_data_frame           function         <function is_data_frame at 0x1353458a0>
# json                    module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# message                 str              We are testing del
# my_module               module           <module 'my_module' from <...>data_types/my_module.py'>
# no1                     int              20
# no2                     int              20
# quiz_percentage         int              200
# session_no              str              6
# sys                     module           <module 'sys' (built-in)>
# text                    str              Here is a sequence 'AACGT'
# this                    module           <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %%
# assign/reassign a value and check the content
message = None

# %%
message

# %%
print(message)
# Out:
# None

# %%
# Remove value - assign the None value to the variable
session_no = None

# %%
print(session_no)
# Out:
# None

# %%
# check the value
session_no

# %%
# use print if nothing is displayed
print(session_no)
# Out:
# None

# %% [markdown]
# What is the type of None - check with the function <b>type()</b>

# %%
type(None)
# Out:
# NoneType

# %%
type(session_no)
# Out:
# NoneType

# %%
type(1)
# Out:
# int

# %%
type(int)
# Out:
# type

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
(1).numerator
# Out:
# 1

# %%
a.numerator
# Out:
# 0

# %%
dir(1)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
(1).is_integer()
# Out:
# True

# %%
# %whos
# Out:
# Variable                Type             Data/Info
# --------------------------------------------------
# NamespaceMagics         MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# a                       int              0
# apples_count            int              10
# attendance_percentage   int              100
# b                       int              1
# dataframe_columns       function         <function dataframe_columns at 0x1353458a0>
# dataframe_hash          function         <function dataframe_hash at 0x135346660>
# dtypes_str              function         <function dtypes_str at 0x1353460c0>
# get_dataframes          function         <function get_dataframes at 0x1353465c0>
# get_ipython             function         <function get_ipython at 0x106f7d3a0>
# getpass                 module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                 module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely    function         <function import_pandas_safely at 0x1352f4a40>
# is_data_frame           function         <function is_data_frame at 0x1352f4860>
# json                    module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# message                 NoneType         None
# my_module               module           <module 'my_module' from <...>data_types/my_module.py'>
# no1                     int              20
# no2                     int              20
# quiz_percentage         int              200
# session_no              NoneType         None
# sys                     module           <module 'sys' (built-in)>
# text                    str              Here is a sequence 'AACGT'
# this                    module           <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %%
session_no

# %%
sequence = "ACGGTT"
print(sequence)
# Out:
# ACGGTT

# %%
print = 2

# %%
print(sequence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 print(sequence)
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print(sequence)
# Out:
# ACGGTT

# %% [markdown]
# Remove the variable session_no from the environment using the <b>del</b> command

# %%
# the del command
del session_no

# %%
# %whos
# Out:
# Variable                Type             Data/Info
# --------------------------------------------------
# NamespaceMagics         MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# a                       int              0
# apples_count            int              10
# attendance_percentage   int              100
# b                       int              1
# dataframe_columns       function         <function dataframe_columns at 0x30847f9c0>
# dataframe_hash          function         <function dataframe_hash at 0x30847f380>
# dtypes_str              function         <function dtypes_str at 0x30847ede0>
# get_dataframes          function         <function get_dataframes at 0x30847f600>
# get_ipython             function         <function get_ipython at 0x106f7d3a0>
# getpass                 module           <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# hashlib                 module           <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely    function         <function import_pandas_safely at 0x30847f7e0>
# is_data_frame           function         <function is_data_frame at 0x30847f6a0>
# json                    module           <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# message                 NoneType         None
# my_module               module           <module 'my_module' from <...>data_types/my_module.py'>
# no1                     int              20
# no2                     int              20
# quiz_percentage         int              200
# sequence                str              ACGGTT
# sys                     module           <module 'sys' (built-in)>
# text                    str              Here is a sequence 'AACGT'
# this                    module           <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %% [markdown]
# Now let's try to see what value variable <i>session_no</i> has<br>
# What do we expect?

# %%
session_no
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 session_no
#
# NameError: name 'session_no' is not defined

# %% [markdown]
# python complained!
# <img src='http://greenlining.org/wp-content/uploads/2013/10/COMPLAIN.jpg' width="200"/>
#
# http://greenlining.org/wp-content/uploads/2013/10/COMPLAIN.jpg

# %%
session_no = 5 * (b + b) + a

# %%
session_no
# Out:
# 10

# %%
# assign a value to a new variable
gpa = 4.0
gpa
# Out:
# 4.0

# %%
type(gpa)
# Out:
# float

# %%
# assign a different type of data to the variable
gpa = "A+"

# %%
gpa
# Out:
# 'A+'

# %%
# check type

type(gpa)
# Out:
# str

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
str.capitalize("test")
# Out:
# 'Test'

# %%
"test".capitalize()
# Out:
# 'Test'

# %%
sequence
# Out:
# 'ACGGTT'

# %%
sequence.lower()
# Out:
# 'acggtt'

# %%
# ?str.capitalize
# Out:
# Signature: str.capitalize(self, /)
# Docstring:
# Return a capitalized version of the string.
#
# More specifically, make the first character have upper case and the rest lower
# case.
# Type:      method_descriptor

# %%
help("test".capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %% [markdown]
# Typing is dynamic but strict in python (objects have type).
#
#
# The principal <b>built-in types</b> are numerics, sequences, mappings, classes, instances and exceptions.<br>
# Numeric Types — <b>int (subtype: bool), float, complex.</b><br>
# Sequence Types — <b>str, list, tuple, range.</b>
#
#
# There are two major categories: mutable and immutable types.<br>
# <b>Immutable</b> variables <b>cannot be changed</b><br>
# <b>Mutable</b> variables <b>can be changed</b>.<br>
#
# <b>Integers, Floats, Strings, Tuples, Booleans</b> are <b>immutable.</b><br>
# <b>Lists, dictionaries, sets</b> are <b>mutable types.</b><br>
#
# https://docs.python.org/3/library/stdtypes.html

# %% [markdown]
# ### Numeric
# Basic math operations: <b>int</b> (natural numbers), <b>float</b> (decimal numbers), <b>complex</b><br>
# Integer, arbitrarily long, convert from floats or strings with int()<br>
# Floats, convert from str or int types with float()<br>
# Convert to string with str()<br>

# %% [markdown]
# <b>No automatic coercion of  types, explicit conversion only</b><br>
# <b>Exception: print() - converts to strings where possible</b>

# %% [markdown]
# ```python
# a=10
# b=20
# ```
#
#
# |     Operator        |                                                                                                                            Description                                                                                                                           |                          Example                          |
# |----------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------|
# | + Addition          | Adds values on either side of the operator.                                                                                                                                                                                                                      | a + b = 30                                                |
# | - Subtraction       | Subtracts right hand operand from left hand operand.                                                                                                                                                                                                             | a – b = -10                                               |
# | * Multiplication    | Multiplies values on either side of the operator                                                                                                                                                                                                                 | a * b = 200                                               |
# | / Division          | Divides left hand operand by right hand operand                                                                                                                                                                                                                  | b / a = 2                                                 |
# | % Modulus           | Divides left hand operand by right hand operand and returns remainder                                                                                                                                                                                            | b % a = 0                                                 |
# | ** Exponent         | Performs exponential (power) calculation on operators                                                                                                                                                                                                            | a\*\*b =10 to the power 20                                  |
# | //  Floor Division  | The division of operands where the result is the quotient in which the digits <br>after the decimal point are removed. But if one of the  operands is negative, <br>the result is floored, i.e., rounded away from zero  (towards negative infinity) | 9//2 = 4 and 9.0//2.0 = 4.0, -11//3 = -4, -11.0//3 = -4.0 |
#
# https://www.tutorialspoint.com/python/arithmetic_operators_example.htm

# %% [markdown]
# Operators precedence - operators have assigned priority (e.g. * before +)
# https://docs.python.org/3/reference/expressions.html#operator-precedence

# %%
a = 10
b = 20

# %%
type(a)
# Out:
# int

# %%
type(float(a))
# Out:
# float

# %%
float(a)
# Out:
# 10.0

# %%
int(4.99)
# Out:
# 4

# %%
str(4)
# Out:
# '4'

# %%
int(4.0)
# Out:
# 4

# %%
float("4.0")
# Out:
# 4.0

# %%
int("4.0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 int("4.0")
#
# ValueError: invalid literal for int() with base 10: '4.0'

# %%
int("4")
# Out:
# 4

# %% [markdown]
# List the methods (functions) and attributes (variables) available for integers using the <b>dir(int)</b> function.

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
dir(5)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
(5).numerator
# Out:
# 5

# %%
(5).is_integer
# Out:
# <function int.is_integer()>

# %%
(5).is_integer()
# Out:
# True

# %% [markdown]
# Functions preceeded by \_\_ (e.g. \_\_lt\_\_ - less than) are special internal functions used by python functions and operators

# %%
session_no = 6.5

# %%
session_no.is_integer()
# Out:
# False

# %% [markdown]
# ##### Check the variables you created and packages you loaded using the magic command <b>%whos</b>

# %%
# %whos
# Out:
# Variable                Type        Data/Info
# ---------------------------------------------
# a                       int         10
# apples_count            int         10
# attendance_percentage   int         100
# b                       int         20
# dataframe_columns       function    <function dataframe_columns at 0x1232fcd60>
# dataframe_hash          function    <function dataframe_hash at 0x1232ff2e0>
# dtypes_str              function    <function dtypes_str at 0x1232fe7a0>
# get_dataframes          function    <function get_dataframes at 0x1232fe200>
# getpass                 module      <module 'getpass' from '/<...>b/python3.12/getpass.py'>
# gpa                     str         A+
# hashlib                 module      <module 'hashlib' from '/<...>b/python3.12/hashlib.py'>
# import_pandas_safely    function    <function import_pandas_safely at 0x1232fe980>
# is_data_frame           function    <function is_data_frame at 0x1232fd8a0>
# json                    module      <module 'json' from '/opt<...>on3.12/json/__init__.py'>
# message                 NoneType    None
# my_module               module      <module 'my_module' from <...>data_types/my_module.py'>
# no1                     int         20
# no2                     int         20
# quiz_percentage         int         200
# session_no              float       6.5
# text                    str         Here is a sequence 'AACGT'
# this                    module      <module 'this' from '/opt<...>/lib/python3.12/this.py'>

# %% [markdown]
# ##### Check the type of the data - use the function <b> type()

# %%
type(session_no)
# Out:
# float

# %%
type(4.0)
# Out:
# float

# %%
# what is the type of int?

# %%
type(int)
# Out:
# type

# %%
# we can also apply dir to variables or data objects not just to types
dir(session_no)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %% [markdown]
# Use the <b>dot notation</b>: <variable/object>.\<method_name\>() to <b>call the method

# %%
session_no.is_integer()
# Out:
# False

# %%
(5.5).is_integer()
# Out:
# False

# %% [markdown]
# Use the <b>dot notation</b>: <variable/object>.\<attribute_name\> to <b>access the attribute of an object

# %%
# paratheses in this case are just a separator
(5).numerator
# Out:
# 5

# %%
(5).denominator
# Out:
# 1

# %%
# paratheses in this case are just a separator
(5)
# Out:
# 5

# %%
((((((5))))))
# Out:
# 5

# %% [markdown]
# Get more information regarding integers using the <b>help(int)</b> function.

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(...)
#  |      Ceiling of an Integral returns itself.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(...)
#  |      Flooring an Integral returns itself.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Convert to a string according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __index__(self, /)
#  |      Return self converted to an integer, if self is suitable for use as an index into a list.
#  |
#  |  __int__(self, /)
#  |      int(self)
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lshift__(self, value, /)
#  |      Return self<<value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __pow__(self, value, mod=None, /)
#  |      Return pow(self, value, mod).
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __rdivmod__(self, value, /)
#  |      Return divmod(value, self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rfloordiv__(self, value, /)
#  |      Return value//self.
#  |
#  |  __rlshift__(self, value, /)
#  |      Return value<<self.
#  |
#  |  __rmod__(self, value, /)
#  |      Return value%self.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __round__(...)
#  |      Rounding an Integral returns itself.
#  |
#  |      Rounding with an ndigits argument also returns an integer.
#  |
#  |  __rpow__(self, value, mod=None, /)
#  |      Return pow(value, self, mod).
#  |
#  |  __rrshift__(self, value, /)
#  |      Return value>>self.
#  |
#  |  __rshift__(self, value, /)
#  |      Return self>>value.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(self, /)
#  |      Returns size in memory, in bytes.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  __trunc__(...)
#  |      Truncating an Integral returns itself.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  as_integer_ratio(self, /)
#  |      Return a pair of integers, whose ratio is equal to the original int.
#  |
#  |      The ratio is in lowest terms and has a positive denominator.
#  |
#  |      >>> (10).as_integer_ratio()
#  |      (10, 1)
#  |      >>> (-10).as_integer_ratio()
#  |      (-10, 1)
#  |      >>> (0).as_integer_ratio()
#  |      (0, 1)
#  |
#  |  bit_count(self, /)
#  |      Number of ones in the binary representation of the absolute value of self.
#  |
#  |      Also known as the population count.
#  |
#  |      >>> bin(13)
#  |      '0b1101'
#  |      >>> (13).bit_count()
#  |      3
#  |
#  |  bit_length(self, /)
#  |      Number of bits necessary to represent self in binary.
#  |
#  |      >>> bin(37)
#  |      '0b100101'
#  |      >>> (37).bit_length()
#  |      6
#  |
#  |  conjugate(...)
#  |      Returns self, the complex conjugate of any int.
#  |
#  |  is_integer(self, /)
#  |      Returns True. Exists for duck type compatibility with float.is_integer.
#  |
#  |  to_bytes(self, /, length=1, byteorder='big', *, signed=False)
#  |      Return an array of bytes representing an integer.
#  |
#  |      length
#  |        Length of bytes object to use.  An OverflowError is raised if the
#  |        integer is not representable with the given number of bytes.  Default
#  |        is length 1.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.  Default is to use 'big'.
#  |      signed
#  |        Determines whether two's complement is used to represent the integer.
#  |        If signed is False and a negative integer is given, an OverflowError
#  |        is raised.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_bytes(bytes, byteorder='big', *, signed=False) from builtins.type
#  |      Return the integer represented by the given array of bytes.
#  |
#  |      bytes
#  |        Holds the array of bytes to convert.  The argument must either
#  |        support the buffer protocol or be an iterable object producing bytes.
#  |        Bytes and bytearray are examples of built-in objects that support the
#  |        buffer protocol.
#  |      byteorder
#  |        The byte order used to represent the integer.  If byteorder is 'big',
#  |        the most significant byte is at the beginning of the byte array.  If
#  |        byteorder is 'little', the most significant byte is at the end of the
#  |        byte array.  To request the native byte order of the host system, use
#  |        `sys.byteorder' as the byte order value.  Default is to use 'big'.
#  |      signed
#  |        Indicates whether two's complement is used to represent the integer.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  denominator
#  |      the denominator of a rational number in lowest terms
#  |
#  |  imag
#  |      the imaginary part of a complex number
#  |
#  |  numerator
#  |      the numerator of a rational number in lowest terms
#  |
#  |  real
#  |      the real part of a complex number

# %%
# help applied to a method/function
help(float.is_integer)

# %%
# help applied to an atttribute

help(int.numerator)
# Out:
# Help on getset descriptor builtins.int.numerator:
#
# numerator
#     the numerator of a rational number in lowest terms

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
dir(float)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %% [markdown]
# Computing the area of a rectangle with the length 6 and width 3.

# %%
#set variables and compute area

length = 60 
width = 3

area = length * width
print(area)
# Out:
# 180

# %%
6 = 10
# Out:
#   Cell In[248], line 1
#     6 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# <font color = "red">EXERCISE</font> <br>
# <br>
# We have a temperature of 27 degrees Celsius.
# Write instructions that transform that temperature in degrees Farenheit and display the result.
#
# > Formula: &deg;F = &deg;C * 1.8 + 32

# %%
### Write your solution in the following cells

temp_C = 27
temp_C
# Out:
# 27

# %%
temp_F = temp_C*1.8 + 32
temp_F
# Out:
# 80.6

# %% [markdown]
# ##### Check the variables you created and packages you loaded using the magic command <b>%whos</b>

# %%
# %whos

# %% [markdown]
# ##### Check the type of the data - use the function <b> type()

# %%
type(4.0)
# Out:
# float

# %% [markdown]
# Float division

# %%
# examples 

type(4/2)
# Out:
# float

# %%
4/2
# Out:
# 2.0

# %%
# Int division

4//2
# Out:
# 2

# %%
5//2
# Out:
# 2

# %% [markdown]
# Explicit conversion

# %%
# examples

float(4)
# Out:
# 4.0

# %% [markdown]
# Remainder/modulo: <b>%</b>

# %%
# example

4%2
# Out:
# 0

# %%
4%3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %% [markdown]
# Exponent: <b>**</b>

# %%
# example

5**2
# Out:
# 25

# %%
25**(1/2)
# Out:
# 5.0

# %%
# exponent used to compute squared root and inverse of a number (negative fraction exponent)
5**(-1)
# Out:
# 0.2

# %%
25**(-0.5)
# Out:
# 0.2

# %%
dir(math)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[292], line 1
# ----> 1 dir(math)
#
# NameError: name 'math' is not defined

# %%
import math

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# ?math.ceil
# Out:
# Signature: math.ceil(x, /)
# Docstring:
# Return the ceiling of x as an Integral.
#
# This is the smallest integer >= x.
# Type:      builtin_function_or_method

# %%
math.ceil(5.2)
# Out:
# 6

# %% [markdown]
# Operations implemented between different data types
# * string repetition - multiply string by integer
# * string concateneation - add strings

# %%
number = 10
message = "Hey!"
message * number
# Out:
# 'Hey!Hey!Hey!Hey!Hey!Hey!Hey!Hey!Hey!Hey!'

# %%
message + number

# %%
message + str(number)

# %% [markdown]
# ### Boolean
# Boolean is a subtype of integer<br>
# <b>True</b>, <b>False</b> values<br>
# 1 == True, 0 == False<br>
# empty structure == False<br>

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Check if a variable value or a value is of a certain type:
# ```python
# isinstance(variable/value, type)
# ```

# %%
isinstance(True, bool)
# Out:
# True

# %%
# bool is a subtype of int
isinstance(True, int)
# Out:
# True

# %%
isinstance(True, bool)
# Out:
# True

# %%
# check the functions/methods available
dir(bool)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
cond_result = True
cond_result
# Out:
# True

# %%
cond_result1 = False
cond_result1
# Out:
# False

# %% [markdown]
# Logical operators <br><br>
# <b>not</b> <br>
# <b>and</b> <br>
# <b>or</b> <br>

# %% [markdown]
# |A               | B              | A and B       | A *or* B       |
# | ---            | ---            | -------       | ------         |
# |<ins>True</ins> |<ins>True<ins>  |<ins>True</ins>|True            |
# |True            |False           |False          |True            |
# |False           |True            |False          |True            |
# |<ins>False</ins>|<ins>False</ins>|False          |<ins>False</ins>|

# %%
# negate logical variable
not cond_result
# Out:
# False

# %%
# check if two results are true at the same time
cond_result and cond_result1
# Out:
# False

# %%
# check if at least one of the results is true
cond_result or cond_result1
# Out:
# True

# %% [markdown]
# Comparison operators:
#
# |<b>Operator</b>  | Description  |
# | --------------- | ------------ |
# |<b>< </b>        | strictly less than|
# |<b><=</b>        | less than or equal|
# |<b>\></b>        | strictly greater than|
# |<b>>=</b>        | greater than or equal|
# |<b>==</b>        | equal|
# |<b>!=</b>        | not equal|
# |<b>is</b>        | object identity|
# |<b>is not</b>    | negated object identity|

# %% [markdown]
# <b>The use of comparison operators typically has a result of boolean type

# %%
cond_result = 2>=3
cond_result
# Out:
# False

# %%
#examples

True + True
# Out:
# 2

# %%
3 and 5 and 0 and 7
# Out:
# 0

# %%
3 and "hello there" and "" and 7
# Out:
# ''

# %%
# any number non 0 can be interpreted as TRUE and 0 can be interpreted as FALSE

6 or 0
# Out:
# 6

# %%
# any non-empty value of any type can be interpreted as TRUE and 
# the empty value can be interpreted as FALSE

"" or 5 or "Hello"
# Out:
# 5

# %% [markdown]
# <font color = "red">EXERCISE</font> <br><br>
# Assign a numeric value to a variable DNA_seq_length.<br>
# Write a composite condition to check if the variable is in the range 10 to 100.<br>
# Write a composite condition to check if the variable is lower than 50 or higher than 1000.<br>
# Write a composite condition to check if the variable is lower than 200 or higher than 1000 and if it can be divided by 3 or 9. <br>

# %%
### Write your solution in the following cells
DNA_seq_length = 27
cond1 = 10 < DNA_seq_length < 100
cond2 = 50 > DNA_seq_length or 1000 < DNA_seq_length
cond3 = (200 > DNA_seq_length or 1000 < DNA_seq_length) and (DNA_seq_length%3==0 or DNA_seq_length%9==0)
print(cond1, cond2, cond3)
# Out:
# True True True

# %%
DNA_seq_length=6
not DNA_seq_length%3
# Out:
# True

# %% [markdown]
# #### Operator precedence
# https://docs.python.org/3/reference/expressions.html#operator-precedence

# %% [markdown]
# Operators to use with boolean values:
# - all numerical operators (bool is a subtype of int)
# - logical operators
#
# | Operation | Result                               |
# |-----------|--------------------------------------|
# | x or y    | if x is true, then x, else y         |
# | x and y   | if x is false, then x, else y        |
# | not x     | if x is false, then True, else False |
#
# List of operators:
# - https://docs.python.org/3/library/operator.html#mapping-operators-to-functions

# %% [markdown]
# Operators precedence - operators have assigned priority (e.g. * before +) https://docs.python.org/3/reference/expressions.html#operator-precedence

# %%
# operators like or, and, not consider the operands as boolean

not ""
# Out:
# True

# %%
not 100
# Out:
# False

# %%
not "good"
# Out:
# False

# %%
# bitwise operators:

3 and 4
# Out:
# 4

# %%
3 | 4
# Out:
# 7

# %%
# 3 | 4 is:
# 3=011 or
# 4=100
#   111 = 7

3 | 4
# Out:
# 7

# %%
# 3 & 4 is:
# 3=011 and
# 4=100
#   000 = 0

3 & 4
# Out:
# 0

# %% [markdown]
# ### String - text between single, double or triple quotes (docstrings - allow for newlines)

# %%
# assign a string to a variable
text = "56"

# %%
text[1]
# Out:
# '6'

# %%
type('hello')
# Out:
# str

# %%
type(text)

# %%
# convert to int
int(text)
# Out:
# 56

# %%
# convert int to text
str(4)
# Out:
# '4'

# %% [markdown]
# List the methods (the functions) and attributes available for strings using the <b>dir(str)</b> function.

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# Functions preceeded by \_\_ (e.g. \_\_lt\_\_ - less than) are special internal functions used by python functions and operators

# %% [markdown]
# Use the <b>dot notation</b>: <variable/object>.\<method_name\>() to <b>call the method

# %%
"AACGT".lower()
# Out:
# 'aacgt'

# %%
"AACGAT".count("A")
# Out:
# 3

# %%
# ?str.strip
# Out:
# Signature: str.strip(self, chars=None, /)
# Docstring:
# Return a copy of the string with leading and trailing whitespace removed.
#
# If chars is given and not None, remove characters in chars instead.
# Type:      method_descriptor

# %%
test_text = "     Hello there     \t     "
test_text
# Out:
# '     Hello there     \t     '

# %%
print(test_text)
# Out:
#      Hello there

# %%
test_text.strip()
# Out:
# 'Hello there'

# %%
# ?str.rpartition
# Out:
# Signature: str.rpartition(self, sep, /)
# Docstring:
# Partition the string into three parts using the given separator.
#
# This will search for the separator in the string, starting at the end. If
# the separator is found, returns a 3-tuple containing the part before the
# separator, the separator itself, and the part after it.
#
# If the separator is not found, returns a 3-tuple containing two empty strings
# and the original string.
# Type:      method_descriptor

# %%
my_text2 = test_text.strip().replace(" ","-")

# %%
my_text2
# Out:
# 'Hello-there'

# %%
my_text2.rpartition("-")
# Out:
# ('Hello', '-', 'there')

# %%
'He-llo-there'.rpartition("-")
# Out:
# ('He-llo', '-', 'there')

# %% [markdown]
# <font color = "red">EXERCISE</font> <br><br>
# Test more of the string functions: upper(), strip(), ...<br><br>

# %%
### Write your solution in the following cells

# %% [markdown]
# Get more information regarding the string methods using <b>help(str.method_name)</b>.

# %%
message = "End of session"

# %%
help(message.endswith)
# Out:
# Help on built-in function endswith:
#
# endswith(...) method of builtins.str instance
#     S.endswith(suffix[, start[, end]]) -> bool
#
#     Return True if S ends with the specified suffix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     suffix can also be a tuple of strings to try.

# %%
# ?message.endswith
# Out:
# Docstring:
# S.endswith(suffix[, start[, end]]) -> bool
#
# Return True if S ends with the specified suffix, False otherwise.
# With optional start, test S beginning at that position.
# With optional end, stop comparing S at that position.
# suffix can also be a tuple of strings to try.
# Type:      builtin_function_or_method

# %%
message.endswith("on")
# Out:
# True

# %%
message.endswith("on ")
# Out:
# False

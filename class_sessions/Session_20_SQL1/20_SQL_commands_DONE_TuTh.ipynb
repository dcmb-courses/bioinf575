# %% [markdown]
# ## SQL - Major SQL commands
# ### BIOINF 575 - Fall 2022

# %% [markdown]
# ##### RESOURCES
# https://sqlite.org/index.html
# https://www.sqlite.org/fullsql.html
# https://docs.python.org/3/library/sqlite3.html
# https://www.sqlite.org/lang_aggfunc.html
# https://www.sqlitetutorial.net/sqlite-create-table/
# https://www.sqlite.org/syntaxdiagrams.html
# https://www.tutorialspoint.com/python_network_programming/python_databases_and_sql.htm
# https://www.tutorialspoint.com/python/python_database_access.htm
# https://www.python-course.eu/sql_python.php
# https://www.sqlalchemy.org/library.html#reference
# https://docs.sqlalchemy.org/en/13/orm/
# https://docs.sqlalchemy.org/en/14/orm/tutorial.html#version-check
# https://towardsdatascience.com/sql-in-python-for-beginners-b9a4f9293ecf
# https://database.guide/2-sample-databases-sqlite/
# https://www.sqlitetutorial.net/sqlite-sample-database/

# %% [markdown]
# #### What is a database?
#
# * Is an organized collection of data (files)
# * A way to store and retrieve that information
# * A relational database is structured to recognize relations between the data elements
#
#
# *  A collection of data
#
#         * Dictionary
#             {"EGFR":6.8, "MYC": 4.5, "WNT1":11.7}
#
#         * Tab-separated text file, or pd.DataFrame
#
#
# | GeneID  | GeneSymbol  | ExpressionValue  |
# |---------|-------------|------------------|
# | 7471    | WNT1        |             11.7 |
# | 4609    | MYC         |              4.5 |
# | 1956    | EGFR        |              6.8 |
#
#
# Entity-Relationship Diagram - shows the relations between tables in a relational database
# - tables are connected by fields (columns) that are common - called keys
#
#
# https://dcm.uhcl.edu/yue/courses/csci4333/current/notes/model/ERDiagram.html
#
#
# <img src = https://dcm.uhcl.edu/yue/courses/csci4333/current/notes/model/ER1_1.png width = 450 />
#
# Relationship diagram as shown by the Relational Database Management Systems (RDBM)
#
# <img src = https://dcm.uhcl.edu/yue/courses/csci4333/current/notes/model/Relationship_1.png width = 600 />
#
#
#
# More examples:
#
# https://www.sqlitetutorial.net/wp-content/uploads/2015/11/sqlite-sample-database-color.jpg
# https://upload.wikimedia.org/wikipedia/commons/b/b8/Sql_hospital.png
# https://www.researchgate.net/profile/Adam_Richards3/publication/282134102/figure/fig3/AS:289128232046602@1445944950296/Database-entity-diagram-Data-collected-from-NCBI-the-Gene-Ontology-and-UniProt-are.png
#
#
#
#
# #### Relational Database Management Systems (RDBMS)
# * Software programs such as Oracle, MySQL, SQLServer, DB2, postgreSQL, SQLite
# * They handle the data storage, indexing, logging, tracking and security (access)
# * They have a very fine-grained way of granting permissions to users at the level of commands that may be used
#     * Create a database
#     * Create a table
#     * Update or insert data
#     * View certain tables ... and many more
# * An important part of learning databases is to understand the type of data which is stored in columns and rows.
# * Likewise when we get to the database design section, it is critically important to know what type of data you will be modeling and storing (and roughly how much, in traditional systems)
# * Exactly which types are available depends on the database system
#
#
#
# #### Why use databases and Relational Database Management Systems?
# * Easy, efficient, secure, collaborative management of data that maintains data integrity
#
# #### What is the Structured Query Language (SQL) ?
# * SQL is the standard language for relational database management systems
# * SQL is used to communicate with a database
#
# #### Why SQLite?
# SQLite is a C library that provides a lightweight disk-based database that doesn’t require a separate server process and allows accessing the database using a nonstandard variant of the SQL query language. Some applications can use SQLite for internal data storage.
# * SQLite is often the technology of choice for small applications, particularly those of embedded systems and devices like phones and tablets, smart appliances, and instruments.
# * It’s also possible to prototype an application using SQLite and then port the code to a larger database such as PostgreSQL or Oracle.
#
# #### Integrated Development Environment (IDE)
#
# There are many tools:
# ##### https://dbeaver.io - recommended, please install it for the next session
#
# <img src = https://github.com/dbeaver/dbeaver/wiki/images/ug/SQL-Editor.png width = 600/>
#
# https://github.com/dbeaver/dbeaver/wiki/SQL-Editor
#
# Other IDE tools:
# https://www.adminer.org
# https://razorsql.com
# https://sqlitebrowser.org
# https://towardsdatascience.com/10-best-sql-editor-tools-in-the-market-126acd64ba06
# https://learnsql.com/blog/best-sql-editor/
#
#
# #### sqlite3
# The sqlite3 module in the Python standard library provides a SQL interface to communicate with databases.<br>
# https://docs.python.org/3/library/sqlite3.html
#
# Once you have a `Connection`, you can create a `Cursor` object and call its execute() method to perform SQL commands.
#
# `Cursor` objects represent a database cursor, which is used to manage the context of a fetch/retrieval operation.
# A call to the `Cursor`'s execute() method is used to perform SQL commands.
#
# #### SQLite uses a greatly simplified set of data types:
# * INTEGER - numeric
# * REAL - numeric
# * TEXT – text of any length
#     * Dates are held as text
# * BLOB – binary large objects
#     * Such as images

# %% [markdown]
# #### The data
#
# https://datacarpentry.org/python-ecology-lesson/
#
# Download the database file `portal_mammals.sqlite` from:
# https://datacarpentry.org/python-ecology-lesson/setup.html
# "
# The data we will be using is a time-series for a small mammal community in southern Arizona.
# This is part of a project studying the effects of rodents and ants on the plant community that has been running for almost 40 years.
# The rodents are sampled on a series of 24 plots, with different experimental manipulations controlling which rodents are allowed to access which plots.
# "
# https://datacarpentry.org/sql-ecology-lesson/00-sql-introduction/index.html

# %%
# bring into the environment the  functionality that 
# can be used to connect to a database

from sqlite3 import connect

'''    
    Establish a connection to the database.
    This statement creates the file at the given path if it does not exist and that will be an empty database.
    The file was provided in this case so the statement should just establish the connection.
'''

# create a connection object to be able to acceess the database

connection = connect('portal_mammals.sqlite')

# create a cursor to interact with the database and 
# send commands to the database 

cursor = connection.cursor()

# %% [markdown]
# #### The cursor and the connection should be closed when we no loger run queries.
# ```python
# cursor.close()
# connection.close()
# ```
#
# We are still using them so we keep them open for now.
# After we close them, we should run the above cell again to reestablish the access to the database.

# %%
# what is the type of the connection object?

type(connection)
# Out:
# sqlite3.Connection

# %%
# what can the connection object do? 
# look at only for non __ methods and attributes

[elem for elem in dir(connection) if not elem.startswith("__")]
# Out:
# ['DataError',
#  'DatabaseError',
#  'Error',
#  'IntegrityError',
#  'InterfaceError',
#  'InternalError',
#  'NotSupportedError',
#  'OperationalError',
#  'ProgrammingError',
#  'Warning',
#  'backup',
#  'close',
#  'commit',
#  'create_aggregate',
#  'create_collation',
#  'create_function',
#  'cursor',
#  'enable_load_extension',
#  'execute',
#  'executemany',
#  'executescript',
#  'in_transaction',
#  'interrupt',
#  'isolation_level',
#  'iterdump',
#  'load_extension',
#  'rollback',
#  'row_factory',
#  'set_authorizer',
#  'set_progress_handler',
#  'set_trace_callback',
#  'text_factory',
#  'total_changes']

# %%
# what is the type of the cursor object?

type(cursor)
# Out:
# sqlite3.Cursor

# %%
# what can the cursor object do? 
# look at only for non __ methods and attributes

[elem for elem in dir(cursor) if not elem.startswith("__")]
# Out:
# ['arraysize',
#  'close',
#  'connection',
#  'description',
#  'execute',
#  'executemany',
#  'executescript',
#  'fetchall',
#  'fetchmany',
#  'fetchone',
#  'lastrowid',
#  'row_factory',
#  'rowcount',
#  'setinputsizes',
#  'setoutputsize']

# %% [markdown]
# ____
#
# #### Major SQL commands: SELECT, INSERT, DELETE, UPDATE
#
# ____
#
# #### SELECT - Retrieves data from one or more tables and doesn’t change the data at all
#
# <img src = http://www.tutorialscan.com/wp-content/uploads/2018/04/sql_select.jpg width = 300 />
#
# http://www.tutorialscan.com/wp-content/uploads/2018/04/sql_select.jpg
#
# #### A more complex diagram with all the options is available at:
# #### https://www.sqlite.org/syntaxdiagrams.html#select-stmt
#
# #### Description of each of the options:
# * **SELECT**  * (means all columns), or the comma separated names of the columns of data you wish to return
#     * Returns columns (left to right) in the order received.
#     * '*' selects ALL rows and ALL columns and returns them by column order and row_id
# * **FROM** is the table source or sources (comma separated)
# * **WHERE** (optional)** is the predicate clause: conditions for the query
#     * Evaluates to True or False for each row
#     * This clause almost always includes Column-Value pairs.
#     * Omitting the Where clause returns ALL the records in that table.
#     * Note: the match is case sensitive
# * **ORDER BY (optional)** indicates a sort order for the output data
#     * default is row_id, which can be very non-intuitive
#     * ASCending or DESCending can be appended to change the sort order.  (ASC is default)
# * **GROUP BY (optional)** groups by a column and creates summary data for a different column
# * **HAVING (optional)** allows restrictions on the rows selected
#     * a GROUP BY clause is required before HAVING
# * **LIMIT (optional)** reduces the number of rows retrieved to the number provided after this clause
# * In most SQL clients, the ";" indicates the end of a statement and requests execution

# %%
# In every SQLite database, there is a special table: sqlite_master
# sqlite_master -  describes the contents of the database

# the SQL command can be ran as is when using a Integrated Development Environment 
# e.g. DBeaver

sql = '''
SELECT type, name 
FROM sqlite_master LIMIT 5;'''
cursor.execute(sql)

# %%
list(cursor)
# Out:
# [('table', 'surveys'), ('table', 'species'), ('table', 'plots')]

# %%
# look at the help of the fetchall method for the cursor 
help(cursor.fetchall)
# Out:
# Help on built-in function fetchall:
#
# fetchall(...) method of sqlite3.Cursor instance
#     Fetches all rows from the resultset.

# %%
cursor.fetchall()
# Out:
# []

# %%
sql = '''
SELECT name,type 
FROM sqlite_master;
'''
cursor.execute(sql)
cursor.fetchall()
# Out:
# [('surveys', 'table'), ('species', 'table'), ('plots', 'table')]

# %%
sql = '''
SELECT name,type 
FROM sqlite_master;
'''
cursor.execute(sql)

# use a for loop to get the rows in the result one by one
for row in cursor: 
    print(row)
# Out:
# ('surveys', 'table')
# ('species', 'table')
# ('plots', 'table')

# %%
sql = '''
SELECT name,type 
FROM sqlite_master;
'''
cursor.execute(sql)

# use fetchone retrieve just one row from the results
cursor.fetchone()
# Out:
# ('surveys', 'table')

# %%
# See the result header

cursor.description
# Out:
# (('name', None, None, None, None, None, None),
#  ('type', None, None, None, None, None, None))

# %%
def get_header(cursor):
    '''
    Makes a tab delimited header row from the cursor description.
    Arguments:
        cursor: a cursor after a select query
    Returns:
        string: A string consisting of the column names separated by tabs, no new line
    '''
    return '\t'.join([row[0] for row in cursor.description])

# %%
get_header(cursor)
# Out:
# 'name\ttype'

# %%
print(get_header(cursor))
# Out:
# name	type

# %% [markdown]
# #### Different ways to retrieve results - observe the different data structures displayed

# %%
# we already have the query in the sql variable

sql
# Out:
# '\nSELECT name,type \nFROM sqlite_master;\n'

# %%
# See the result

cursor.execute(sql)
print("Iterate through the cursor:")
for row in cursor: 
    print(row)
    
print()

cursor.execute(sql)
print("Use the Cursor fetchall() method:")
cursor.fetchall()
# Out:
# Iterate through the cursor:
# ('surveys', 'table')
# ('species', 'table')
# ('plots', 'table')
#
# Use the Cursor fetchall() method:
# [('surveys', 'table'), ('species', 'table'), ('plots', 'table')]

# %%
# note that if you have a large result 
# this function will try to make a very large string from it
# so it is recommended for results with less than 10 rows and 10 columns
# for other cases use the for loop to go through the rows in the result 

def get_results(cursor):
    '''
    Makes a tab delimited table from the cursor results.
    Arguments:
        cursor: a cursor after a select query
    Returns:
        string: A string consisting of the column names separated by tabs, no new line
    ''' 
    res = list()
    for row in cursor.fetchall():        
        res.append('\t'.join(list(map(str,row))))
    return "\n".join(res)

# %%
# use the functions we created for a nice display of the results

cursor.execute(sql)

print(get_header(cursor))
print(get_results(cursor))
# Out:
# name	type
# surveys	table
# species	table
# plots	table

# %% [markdown]
# ##### WHERE clause example (-- denotes comment)

# %%
# more examples with comments later
# in the WHERE clause we put conditions to filter the data

sql = '''
SELECT name
FROM sqlite_master 
WHERE type = "table"; -- condition that allows the selection of specific rows
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name
# surveys
# species
# plots

# %%
# Selects all columns (*) of the species table 
# retrieves only 10 rows due to the LIMIT clause
# The first column is the species id

sql = '''
SELECT *
FROM species LIMIT 20;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	genus	species	taxa
# AB	Amphispiza	bilineata	Bird
# AH	Ammospermophilus	harrisi	Rodent
# AS	Ammodramus	savannarum	Bird
# BA	Baiomys	taylori	Rodent
# CB	Campylorhynchus	brunneicapillus	Bird
# CM	Calamospiza	melanocorys	Bird
# CQ	Callipepla	squamata	Bird
# CS	Crotalus	scutalatus	Reptile
# CT	Cnemidophorus	tigris	Reptile
# CU	Cnemidophorus	uniparens	Reptile
# CV	Crotalus	viridis	Reptile
# DM	Dipodomys	merriami	Rodent
# DO	Dipodomys	ordii	Rodent
# DS	Dipodomys	spectabilis	Rodent
# DX	Dipodomys	sp.	Rodent
# EO	Eumeces	obsoletus	Reptile
# GS	Gambelia	silus	Reptile
# NL	Neotoma	albigula	Rodent
# NX	Neotoma	sp.	Rodent
# OL	Onychomys	leucogaster	Rodent

# %%
sql = '''
SELECT *
FROM species 
WHERE species_id = "DM";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	genus	species	taxa
# DM	Dipodomys	merriami	Rodent

# %% [markdown]
# ##### Aliasing column names to make them easier to understand
# - add a new name for a column next to the column name using quotes if the alias contains spaces, the AS keyword can also be used
#     - e.g.: column_name AS "Alias name"
#     - e.g.: column_name "Alias name"
#     - e.g.: column_name Alias_name

# %%
# example of aliasing columns

sql = '''
SELECT species_id ID, species AS "Species Name"
FROM species LIMIT 5;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# ID	Species Name
# AB	bilineata
# AH	harrisi
# AS	savannarum
# BA	taylori
# CB	brunneicapillus

# %%
# we can use aggregate functions to summarize data
# COUNT returns a single number, which is the count of all rows in the table

sql = '''
SELECT count(*) FROM species;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# count(*)
# 54

# %%
sql = '''
SELECT count(species_id) AS 'Number of species' 
FROM species;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# Number of species
# 54

# %%
# select first 50 rows from the surveys table - all columns

select_50_surveys = """
SELECT *
FROM surveys
limit 50;
"""

cursor.execute(select_50_surveys)
# cursor.fetchall()
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 1	7	16	1977	2	NL	M	32.0	None
# 2	7	16	1977	3	NL	M	33.0	None
# 3	7	16	1977	2	DM	F	37.0	None
# 4	7	16	1977	7	DM	M	36.0	None
# 5	7	16	1977	3	DM	M	35.0	None
# 6	7	16	1977	1	PF	M	14.0	None
# 7	7	16	1977	2	PE	F	None	None
# 8	7	16	1977	1	DM	M	37.0	None
# 9	7	16	1977	1	DM	F	34.0	None
# 10	7	16	1977	6	PF	F	20.0	None
# 11	7	16	1977	5	DS	F	53.0	None
# 12	7	16	1977	7	DM	M	38.0	None
# 13	7	16	1977	3	DM	M	35.0	None
# 14	7	16	1977	8	DM	None	None	None
# 15	7	16	1977	6	DM	F	36.0	None
# 16	7	16	1977	4	DM	F	36.0	None
# 17	7	16	1977	3	DS	F	48.0	None
# 18	7	16	1977	2	PP	M	22.0	None
# 19	7	16	1977	4	PF	None	None	None
# 20	7	17	1977	11	DS	F	48.0	None
# 21	7	17	1977	14	DM	F	34.0	None
# 22	7	17	1977	15	NL	F	31.0	None
# 23	7	17	1977	13	DM	M	36.0	None
# 24	7	17	1977	13	SH	M	21.0	None
# 25	7	17	1977	9	DM	M	35.0	None
# 26	7	17	1977	15	DM	M	31.0	None
# 27	7	17	1977	15	DM	M	36.0	None
# 28	7	17	1977	11	DM	M	38.0	None
# 29	7	17	1977	11	PP	M	None	None
# 30	7	17	1977	10	DS	F	52.0	None
# 31	7	17	1977	15	DM	F	37.0	None
# 32	7	17	1977	10	DM	F	35.0	None
# 33	7	17	1977	11	DM	F	36.0	None
# 34	7	17	1977	17	DM	None	None	None
# 35	7	17	1977	13	DM	F	38.0	None
# 36	7	17	1977	16	OT	F	22.0	None
# 37	7	17	1977	11	DM	F	35.0	None
# 38	7	17	1977	17	NL	M	33.0	None
# 39	7	17	1977	11	DM	F	36.0	None
# 40	7	18	1977	20	DM	M	36.0	None
# 41	7	18	1977	23	DM	F	34.0	None
# 42	7	18	1977	18	DS	F	46.0	None
# 43	7	18	1977	21	DM	M	36.0	None
# 44	7	18	1977	18	DM	F	35.0	None
# 45	7	18	1977	22	DM	M	36.0	None
# 46	7	18	1977	19	DM	M	35.0	None
# 47	7	18	1977	18	DM	M	32.0	None
# 48	7	18	1977	20	DM	F	36.0	None
# 49	7	18	1977	12	PP	F	17.0	None
# 50	7	18	1977	18	DM	F	32.0	None

# %%
select_year_surveys = """
SELECT max(year) "Last survey year"
FROM surveys;
"""

cursor.execute(select_year_surveys)
# cursor.fetchall()
print(get_header(cursor))
print(get_results(cursor))
# Out:
# Last survey year
# 2002

# %%
sql = '''
SELECT * 
FROM surveys
LIMIT 20;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 1	7	16	1977	2	NL	M	32.0	None
# 2	7	16	1977	3	NL	M	33.0	None
# 3	7	16	1977	2	DM	F	37.0	None
# 4	7	16	1977	7	DM	M	36.0	None
# 5	7	16	1977	3	DM	M	35.0	None
# 6	7	16	1977	1	PF	M	14.0	None
# 7	7	16	1977	2	PE	F	None	None
# 8	7	16	1977	1	DM	M	37.0	None
# 9	7	16	1977	1	DM	F	34.0	None
# 10	7	16	1977	6	PF	F	20.0	None
# 11	7	16	1977	5	DS	F	53.0	None
# 12	7	16	1977	7	DM	M	38.0	None
# 13	7	16	1977	3	DM	M	35.0	None
# 14	7	16	1977	8	DM	None	None	None
# 15	7	16	1977	6	DM	F	36.0	None
# 16	7	16	1977	4	DM	F	36.0	None
# 17	7	16	1977	3	DS	F	48.0	None
# 18	7	16	1977	2	PP	M	22.0	None
# 19	7	16	1977	4	PF	None	None	None
# 20	7	17	1977	11	DS	F	48.0	None

# %%
# DISTINCT selects  non-duplicated elements (rows)

sql = '''
SELECT month, year FROM surveys LIMIT 5;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))

print()

sql = '''
SELECT DISTINCT month, year FROM surveys LIMIT 5;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# month	year
# 7	1977
# 7	1977
# 7	1977
# 7	1977
# 7	1977
#
# month	year
# 7	1977
# 8	1977
# 9	1977
# 10	1977
# 11	1977

# %%
# Other aggregate functions are available for numerical columns
# https://www.sqlite.org/lang_aggfunc.html
# comments are added using -- in front of the test to comment or using /* comment */ 

sql = '''
SELECT MAX(DISTINCT plot_id) MAX_PID FROM surveys; -- comment LIMIT 5; /* comment */
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# MAX_PID
# 24

# %%
# count the number of rows in surveys
count_surveys = """
SELECT count(record_id)
FROM surveys;
"""

cursor.execute(count_surveys)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# count(record_id)
# 35549

# %%
count_surveys = """
SELECT count(*) "Number of surveys"
FROM surveys;
"""

cursor.execute(count_surveys)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# Number of surveys
# 35549

# %%
select_columns = """
SELECT * 
FROM surveys
LIMIT 1;
"""

cursor.execute(select_columns)
print(get_header(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight

# %%
select_columns = """
SELECT * 
FROM species
LIMIT 1;
"""

cursor.execute(select_columns)
print(get_header(cursor))
# Out:
# species_id	genus	species	taxa

# %%
select_columns = """
SELECT * 
FROM species
LIMIT 1;
"""

cursor.execute(select_columns)
cursor.description
# Out:
# (('species_id', None, None, None, None, None, None),
#  ('genus', None, None, None, None, None, None),
#  ('species', None, None, None, None, None, None),
#  ('taxa', None, None, None, None, None, None))

# %%
# count the number of distinct years in surveys

count_distinct_years = """
SELECT year
FROM surveys;
"""

cursor.execute(count_distinct_years)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# year
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1977
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1978
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1979
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1980
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1981
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1982
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1983
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# 1984
# ...
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002
# 2002

# %%
count_distinct_years = """
SELECT DISTINCT year
FROM surveys;
"""

cursor.execute(count_distinct_years)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# year
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002

# %%
# distinct inside the aggregate function applies to the column and 
# then the aggregate function applies to the result

count_distinct_years = """
SELECT count(DISTINCT year)
FROM surveys;
"""

cursor.execute(count_distinct_years)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# count(DISTINCT year)
# 26

# %%
# distinct outside the aggregate function applies to the result of the aggregate function
count_distinct_years = """
SELECT DISTINCT count(year)
FROM surveys;
"""

cursor.execute(count_distinct_years)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# count(year)
# 35549

# %% [markdown]
# #### WHERE clause operators
# https://www.sqlite.org/lang_expr.html
#
# "<>" ,  != 	inequality <br>
# "<"			less than <br>
# "<=" 			less than or equal <br>
# "="			equal <br>
# ">"			greater than <br>
# ">=" 		greater than or equal <br>
# BETWEEN v1 AND v2	tests that a value to lies in a given range <br>
# EXISTS		test for existence of rows matching query <br>
# IN			tests if a value falls within a given set or query <br>
# IS [ NOT ] NULL	is or is not null <br>
# [ NOT ] LIKE		tests value to see if like or not like another <br>
#
# % is the wildcard in SQL, used in conjunction with LIKE

# %% [markdown]
# ........................................................................
#
# Merriam's kangaroo rat (Dipodomys merriami - DM)
#
# <img src = https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Merriam%27s_Kangaroo_Rat.jpg/440px-Merriam%27s_Kangaroo_Rat.jpg width = 150 />
#
# https://en.wikipedia.org/wiki/Merriam%27s_kangaroo_rat
# ........................................................................

# %%
# we can put multiple conditions in the  where clause 
# combine conditions with AND, OR
# let's see the DM rats that have a weight < 40 and were seen on a specific plot in 1990

sql = '''
SELECT * FROM surveys 
WHERE 
    plot_id = '11' AND 
    species_id = "DM" AND 
    weight < 40 AND 
    year = 1990;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 17221	2	25	1990	11	DM	F	37.0	39.0
# 17550	5	24	1990	11	DM	F	34.0	23.0
# 17649	6	22	1990	11	DM	M	33.0	20.0
# 17730	7	22	1990	11	DM	F	36.0	33.0
# 17808	8	17	1990	11	DM	F	37.0	35.0
# 17816	8	17	1990	11	DM	F	35.0	23.0
# 17874	9	25	1990	11	DM	F	None	39.0
# 17943	10	16	1990	11	DM	F	37.0	39.0
# 18051	11	11	1990	11	DM	F	37.0	38.0
# 18156	12	16	1990	11	DM	F	34.0	37.0
# 18182	12	16	1990	11	DM	F	37.0	37.0

# %%
### select males of the species DS, DM or PF 
## that were seen in plots 11 or 10 
## in 1980 or 1983 in January or March

sql = '''
SELECT * FROM surveys 
WHERE species_id IN ("DS", "DM", "PF") AND
      plot_id IN (10, 11) AND
      year IN (1980, 1983) AND 
      month IN (1,3) AND
      sex = "M";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 2274	1	15	1980	11	DM	M	38.0	37.0
# 2276	1	15	1980	11	DS	M	47.0	132.0
# 2286	1	15	1980	11	DM	M	38.0	47.0
# 2290	1	15	1980	11	DM	M	37.0	49.0
# 2297	1	15	1980	11	DM	M	37.0	45.0
# 2310	1	15	1980	11	DM	M	36.0	48.0
# 2319	1	15	1980	11	DM	M	37.0	26.0
# 2324	1	15	1980	11	DM	M	35.0	49.0
# 2641	3	9	1980	11	DS	M	None	147.0
# 2648	3	9	1980	11	DM	M	None	42.0
# 7179	1	12	1983	11	DM	M	37.0	38.0
# 7186	1	12	1983	11	DM	M	36.0	43.0
# 7223	1	12	1983	11	DM	M	36.0	46.0
# 7492	3	14	1983	11	DM	M	34.0	42.0
# 7493	3	14	1983	11	DM	M	37.0	46.0
# 7498	3	14	1983	11	DM	M	36.0	45.0
# 7519	3	14	1983	11	PF	M	17.0	6.0
# 7525	3	14	1983	11	DM	M	37.0	52.0
# 7537	3	14	1983	11	DM	M	37.0	46.0

# %%
# select DM sightings of individuals with a weight between 30 and 40
# on plots 6, 7, or 8
# in the years 1989 or 1990

sql = '''
SELECT * FROM surveys 
WHERE species_id = 'DM' AND 
      weight BETWEEN 30 AND 40 AND
      plot_id BETWEEN 6 AND 8 AND
      year BETWEEN 1989 AND 1990;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 15469	1	11	1989	8	DM	M	36.0	39.0
# 16161	6	4	1989	8	DM	M	36.0	34.0
# 16201	6	4	1989	8	DM	F	50.0	38.0
# 16306	7	4	1989	8	DM	F	None	32.0
# 16414	7	30	1989	8	DM	F	36.0	36.0
# 16545	10	8	1989	6	DM	M	36.0	40.0
# 16673	11	5	1989	8	DM	F	35.0	39.0
# 16942	1	7	1990	8	DM	F	36.0	38.0
# 17055	1	30	1990	8	DM	F	37.0	39.0
# 17079	1	30	1990	8	DM	F	35.0	35.0
# 17114	1	30	1990	8	DM	F	37.0	36.0
# 17197	2	25	1990	8	DM	F	36.0	38.0
# 17229	2	25	1990	8	DM	F	35.0	40.0
# 17369	3	30	1990	8	DM	F	36.0	39.0
# 17441	4	26	1990	8	DM	F	37.0	39.0
# 17442	4	26	1990	8	DM	F	37.0	40.0
# 17516	5	24	1990	8	DM	M	36.0	32.0
# 17529	5	24	1990	8	DM	M	35.0	30.0
# 17610	6	22	1990	8	DM	M	36.0	37.0
# 17851	9	25	1990	8	DM	F	None	39.0
# 17937	10	16	1990	8	DM	F	35.0	40.0
# 18026	11	11	1990	8	DM	F	36.0	35.0
# 18029	11	11	1990	8	DM	M	37.0	40.0
# 18040	11	11	1990	8	DM	M	36.0	35.0
# 18063	11	11	1990	8	DM	M	36.0	38.0
# 18065	11	11	1990	8	DM	F	36.0	40.0
# 18129	12	16	1990	8	DM	F	36.0	40.0
# 18153	12	16	1990	8	DM	M	37.0	36.0
# 18168	12	16	1990	8	DM	F	35.0	38.0
# 18174	12	16	1990	8	DM	M	37.0	39.0

# %%
# LIKE allows you to look for patterns

sql = '''
SELECT * 
FROM species 
WHERE genus LIKE '%per%'; -- not case sensitive
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	genus	species	taxa
# AH	Ammospermophilus	harrisi	Rodent
# PE	Peromyscus	eremicus	Rodent
# PF	Perognathus	flavus	Rodent
# PH	Perognathus	hispidus	Rodent
# PL	Peromyscus	leucopus	Rodent
# PM	Peromyscus	maniculatus	Rodent
# SS	Spermophilus	spilosoma	Rodent
# ST	Spermophilus	tereticaudus	Rodent

# %%
sql = '''
SELECT * 
FROM species 
WHERE genus LIKE 'per%'; -- not case sensitive
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	genus	species	taxa
# PE	Peromyscus	eremicus	Rodent
# PF	Perognathus	flavus	Rodent
# PH	Perognathus	hispidus	Rodent
# PL	Peromyscus	leucopus	Rodent
# PM	Peromyscus	maniculatus	Rodent

# %%
# Retrieve rows from surveys where the species_id is DM 
# and has been seen in 1990 or 1995 in June-August on plot 1

summer_sightings_90_95_plot1 = """
SELECT * 
FROM surveys
WHERE
    plot_id = 1 AND
    species_id = "dm" AND -- equality operator is case sensistive
    (year = 1990 OR year = 1995) AND 
    month IN (6,7,8);
"""

cursor.execute(summer_sightings_90_95_plot1)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight

# %%
summer_sightings_90_95_plot1 = """
SELECT * 
FROM surveys
WHERE
    plot_id = 1 AND
    species_id = "DM" AND -- equality operator is case sensistive
    (year = 1990 OR year = 1995) AND 
    month IN (6,7,8);
"""

cursor.execute(summer_sightings_90_95_plot1)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 17604	6	21	1990	1	DM	M	36.0	43.0
# 17656	7	21	1990	1	DM	M	35.0	43.0
# 17664	7	21	1990	1	DM	M	38.0	45.0
# 17666	7	21	1990	1	DM	M	37.0	46.0
# 17742	8	16	1990	1	DM	F	36.0	43.0
# 17748	8	16	1990	1	DM	M	37.0	45.0
# 17767	8	16	1990	1	DM	M	37.0	41.0
# 22301	6	7	1995	1	DM	F	38.0	50.0
# 22363	6	27	1995	1	DM	M	38.0	48.0
# 22435	7	20	1995	1	DM	F	35.0	35.0
# 22554	8	26	1995	1	DM	F	36.0	42.0

# %%
# ORDER BY (optional) - indicates a sort order given by a column in the the output data and the sort order: ASC or DESC

sql = '''
SELECT *
FROM surveys 
WHERE month = 6 AND year = 1983 AND sex = "F" AND plot_id BETWEEN 10 AND 20
ORDER BY plot_id  ASC, species_id DESC
--LIMIT 20;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 8016	6	18	1983	11	OT	F	20.0	30.0
# 8046	6	18	1983	11	DS	F	52.0	128.0
# 8010	6	18	1983	11	DO	F	36.0	46.0
# 7938	6	17	1983	12	PP	F	22.0	20.0
# 7970	6	17	1983	12	OT	F	20.0	15.0
# 7936	6	17	1983	12	DO	F	34.0	42.0
# 7962	6	17	1983	12	DO	F	33.0	39.0
# 7957	6	17	1983	12	DM	F	36.0	44.0
# 7980	6	17	1983	12	DM	F	31.0	16.0
# 7981	6	17	1983	13	DM	F	34.0	49.0
# 7989	6	17	1983	13	DM	F	35.0	46.0
# 7953	6	17	1983	14	DO	F	31.0	19.0
# 7972	6	17	1983	14	DO	F	33.0	15.0
# 7976	6	17	1983	14	DO	F	33.0	46.0
# 8031	6	18	1983	15	OL	F	20.0	45.0
# 8033	6	18	1983	15	NL	F	29.0	117.0
# 7934	6	17	1983	17	DM	F	33.0	38.0
# 7968	6	17	1983	18	OT	F	20.0	22.0
# 7959	6	17	1983	18	NL	F	32.0	162.0
# 7977	6	17	1983	18	DS	F	47.0	64.0
# 7983	6	17	1983	19	RM	F	16.0	15.0
# 7986	6	17	1983	19	PF	F	16.0	7.0
# 7937	6	17	1983	20	NL	F	31.0	None
# 7967	6	17	1983	20	NL	F	32.0	150.0
# 7939	6	17	1983	20	DS	F	50.0	111.0
# 7947	6	17	1983	20	DO	F	35.0	41.0
# 7971	6	17	1983	20	DM	F	36.0	None

# %% [markdown]
# ____
# The PRAGMA statement is an SQL extension specific to SQLite and used to modify the operation of the SQLite library or to query the SQLite library for internal (non-table) data.
# https://www.sqlite.org/pragma.html

# %% [markdown]
# ____
# Sqlite3 also has some PRAGMA methods <br>
# This is an SQL extension specific to SQLite that is used to modify the operation of the SQLite library or to query the SQLite library for internal (non-table) data <br>
# https://www.sqlite.org/pragma.html <br>
# The code below shows how to get the schema (columns and columns information)

# %%
# get the information about the data table
# other PRAGMA methods can provide other types of information

sql = 'PRAGMA table_info("species")'
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# cid	name	type	notnull	dflt_value	pk
# 0	species_id	TEXT	0	None	0
# 1	genus	TEXT	0	None	0
# 2	species	TEXT	0	None	0
# 3	taxa	TEXT	0	None	0

# %%
sql = '''SELECT * FROM pragma_table_info("species")  '''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# cid	name	type	notnull	dflt_value	pk
# 0	species_id	TEXT	0	None	0
# 1	genus	TEXT	0	None	0
# 2	species	TEXT	0	None	0
# 3	taxa	TEXT	0	None	0

# %%
sql = '''SELECT * FROM pragma_table_info("surveys")  '''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# cid	name	type	notnull	dflt_value	pk
# 0	record_id	BIGINT	0	None	0
# 1	month	BIGINT	0	None	0
# 2	day	BIGINT	0	None	0
# 3	year	BIGINT	0	None	0
# 4	plot_id	BIGINT	0	None	0
# 5	species_id	TEXT	0	None	0
# 6	sex	TEXT	0	None	0
# 7	hindfoot_length	FLOAT	0	None	0
# 8	weight	FLOAT	0	None	0

# %% [markdown]
# ___

# %%
select_species_id = """
SELECT DISTINCT species_id 
    FROM surveys
    WHERE year = 1997 AND month = 4;
"""

cursor.execute(select_species_id)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id
# DM
# PP
# RM
# PF
# PM
# OT
# PB
# PE
# DO
# OL
# RF

# %%
# SUB-QUERY - we can have a query in a query

sql = '''
SELECT *
FROM species
WHERE species_id IN
    (SELECT DISTINCT species_id 
    FROM surveys
    WHERE year = 1997 AND month = 4); 
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	genus	species	taxa
# DM	Dipodomys	merriami	Rodent
# DO	Dipodomys	ordii	Rodent
# OL	Onychomys	leucogaster	Rodent
# OT	Onychomys	torridus	Rodent
# PB	Chaetodipus	baileyi	Rodent
# PE	Peromyscus	eremicus	Rodent
# PF	Perognathus	flavus	Rodent
# PM	Peromyscus	maniculatus	Rodent
# PP	Chaetodipus	penicillatus	Rodent
# RF	Reithrodontomys	fulvescens	Rodent
# RM	Reithrodontomys	megalotis	Rodent

# %%
# GROUP BY groups by a column and creates summary data for a different column
# count entries for each species_id in surveys

sql = '''
SELECT species_id ID, count(*) AS record_no
FROM surveys 
GROUP BY species_id 
ORDER BY record_no DESC;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# ID	record_no
# DM	10596
# PP	3123
# DO	3027
# PB	2891
# RM	2609
# DS	2504
# OT	2249
# PF	1597
# PE	1299
# NL	1252
# OL	1006
# PM	899
# None	763
# AH	437
# AB	303
# SS	248
# SH	147
# SA	75
# RF	75
# CB	50
# BA	46
# SO	43
# SF	43
# DX	40
# PC	39
# PL	36
# PH	32
# CQ	16
# CM	13
# OX	12
# UR	10
# PI	9
# UP	8
# RO	8
# PG	8
# PX	6
# SU	5
# PU	5
# US	4
# UL	4
# ZL	2
# RX	2
# AS	2
# ST	1
# SC	1
# CV	1
# CU	1
# CT	1
# CS	1

# %%
# specify column in aggregate function and alias the name of the columns

sql = '''
SELECT plot_id as "Plot No", count(record_id) as "Record Number" 
FROM surveys 
GROUP BY plot_id
ORDER BY "Record Number" DESC;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# Plot No	Record Number
# 12	2365
# 2	2194
# 17	2039
# 1	1995
# 4	1969
# 9	1936
# 11	1918
# 8	1891
# 14	1885
# 3	1828
# 6	1582
# 13	1538
# 18	1445
# 22	1399
# 20	1390
# 5	1194
# 19	1189
# 21	1173
# 15	1069
# 24	1048
# 7	816
# 16	646
# 23	571
# 10	469

# %%
# HAVING allows restrictions on the rows used or selected
# a GROUP BY clause is required before HAVING

sql = '''
SELECT plot_id as "Plot No", count(record_id) counts 
FROM surveys 
GROUP BY plot_id
HAVING counts < 1000;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# Plot No	counts
# 7	816
# 10	469
# 16	646
# 23	571

# %%
# HAVING allows restrictions on the rows used or selected
# a GROUP BY clause is required before HAVING

sql = '''
SELECT plot_id as "Plot No", count(record_id) counts 
FROM surveys 
WHERE counts < 1000
GROUP BY plot_id;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [51], in <cell line: 10>()
#       1 # HAVING allows restrictions on the rows used or selected
#       2 # a GROUP BY clause is required before HAVING
#       4 sql = '''
#       5 SELECT plot_id as "Plot No", count(record_id) counts
#       6 FROM surveys
#       7 WHERE counts < 1000
#       8 GROUP BY plot_id;
#       9 '''
# ---> 10 cursor.execute(sql)
#      11 print(get_header(cursor))
#      12 print(get_results(cursor))
#
# OperationalError: misuse of aggregate: count()

# %%
# Select month, year combinations with more than 300 records

month_year_gt_300 = """
SELECT month, year, count(record_id) record_count
FROM surveys
GROUP BY month
HAVING record_count > 300
ORDER BY record_count DESC;
"""

cursor.execute(month_year_gt_300)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# month	year	record_count
# 7	1977	3633
# 3	1978	3390
# 4	1978	3369
# 5	1978	3147
# 10	1977	3126
# 11	1977	3016
# 12	1977	2799
# 2	1978	2796
# 6	1978	2697
# 9	1977	2689
# 1	1978	2518
# 8	1977	2369

# %%
month_year_gt_300 = """
SELECT month, year, count(record_id) record_count
FROM surveys
GROUP BY month, year
HAVING record_count > 300
ORDER BY record_count DESC;
"""

cursor.execute(month_year_gt_300)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# month	year	record_count
# 7	1997	542
# 12	2002	361
# 4	1981	342
# 10	1982	306

# %% [markdown]
# ___
# #### A `PRIMARY KEY` is a very important concept to understand.
# * It is the designation for a column or a set of columns from a table.
# * It is recommended to be a serial value and not something related to the business needs of the data in the table.
#
# * A primary key is used to uniquely identify a row of data; combined with a column name, uniquely locates a data entry
# * A primary key by definition must be `UNIQUE` and `NOT NULL`
# * The primary key of a table, should be a (sequential) non-repeating and not null value
# * Primary keys are generally identified at time of table creation
# * A common method for generating a primary key, is to set the datatype to `INTEGER` and declare `AUTOINCREMENT` which will function when data is inserted into the table
# * Primary keys can be a composite of 2 or more columns that uniquely identify the data in the table

# %% [markdown]
# #### A `FOREIGN KEY` is a column(s) that points to the `PRIMARY KEY` of another table
#
# * The purpose of the foreign key is to ensure referential integrity of the data.
# In other words, only values that are supposed to appear in the database are permitted.<br>
# Only the values that exist in the `PRIMARY KEY` column are allowed to be present in the FOREIGN KEY column.
# Example: A `gene` table has the `PRIMARY KEY` `gene_id`. The GO2_gene GO term is associated with a gene
#
# They are also the underpinning of how tables are joined and relationships portrayed in the database

# %% [markdown]
# #### JOIN tables
#
# * Multiple tables contain different data that we want to retrieve from a single query
# * In order to assemble data as part of a query, a JOIN between tables is needed
# * This is a very common practice, since it’s rare for all the data you want to be in a single table
#
#
# * INNER JOIN - return only those rows where there is matching content in BOTH tables (is the default when JOIN is used)
# * OUTER JOIN - returns all rows from both tables even if one of the tables is blank
# * SELF JOIN - can be used to join a table to itself (through aliasing), to compare data internal to the table
#
# ```sql
# SELECT ... FROM table1 [INNER] JOIN table2 ON conditional_expression
# ```

# %%
sql = '''
SELECT month, day, year, species, genus, plot_id
FROM surveys AS sv
INNER JOIN species AS sp
      ON sv.species_id = sp.species_id
WHERE plot_id = "6" AND 
      year = 2001 AND 
      sex = "F" AND 
      genus LIKE "%on%";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# month	day	year	species	genus	plot_id
# 1	22	2001	torridus	Onychomys	6
# 4	22	2001	hispidus	Sigmodon	6
# 5	27	2001	hispidus	Sigmodon	6
# 5	27	2001	hispidus	Sigmodon	6
# 5	27	2001	torridus	Onychomys	6
# 5	27	2001	torridus	Onychomys	6
# 10	14	2001	torridus	Onychomys	6
# 11	18	2001	torridus	Onychomys	6

# %%
sql = """SELECT name
FROM sqlite_master;
"""

cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name
# surveys
# species
# plots

# %%
sql = """SELECT *
FROM plots;
"""

cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# plot_id	plot_type
# 1	Spectab exclosure
# 2	Control
# 3	Long-term Krat Exclosure
# 4	Control
# 5	Rodent Exclosure
# 6	Short-term Krat Exclosure
# 7	Rodent Exclosure
# 8	Control
# 9	Spectab exclosure
# 10	Rodent Exclosure
# 11	Control
# 12	Control
# 13	Short-term Krat Exclosure
# 14	Control
# 15	Long-term Krat Exclosure
# 16	Rodent Exclosure
# 17	Control
# 18	Short-term Krat Exclosure
# 19	Long-term Krat Exclosure
# 20	Short-term Krat Exclosure
# 21	Long-term Krat Exclosure
# 22	Control
# 23	Rodent Exclosure
# 24	Rodent Exclosure

# %%
join_surveys_plots = """
SELECT *
FROM plots 
 INNER JOIN surveys ON plots.plot_id = surveys.plot_id
LIMIT 20;
"""

cursor.execute(join_surveys_plots)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# plot_id	plot_type	record_id	month	day	year	plot_id	species_id	sex	hindfoot_length	weight
# 1	Spectab exclosure	6	7	16	1977	1	PF	M	14.0	None
# 1	Spectab exclosure	8	7	16	1977	1	DM	M	37.0	None
# 1	Spectab exclosure	9	7	16	1977	1	DM	F	34.0	None
# 1	Spectab exclosure	78	8	19	1977	1	PF	M	16.0	9.0
# 1	Spectab exclosure	80	8	19	1977	1	DS	M	48.0	None
# 1	Spectab exclosure	218	9	13	1977	1	PF	M	13.0	4.0
# 1	Spectab exclosure	222	9	13	1977	1	DS	M	52.0	None
# 1	Spectab exclosure	239	9	13	1977	1	DS	M	48.0	None
# 1	Spectab exclosure	263	10	16	1977	1	DM	M	37.0	40.0
# 1	Spectab exclosure	270	10	16	1977	1	DM	F	36.0	38.0
# 1	Spectab exclosure	276	10	16	1977	1	DS	F	50.0	None
# 1	Spectab exclosure	285	10	16	1977	1	DM	M	36.0	53.0
# 1	Spectab exclosure	352	11	12	1977	1	DM	M	36.0	40.0
# 1	Spectab exclosure	356	11	12	1977	1	DO	F	32.0	44.0
# 1	Spectab exclosure	362	11	12	1977	1	DS	F	51.0	121.0
# 1	Spectab exclosure	365	11	12	1977	1	DM	F	38.0	35.0
# 1	Spectab exclosure	376	11	12	1977	1	PF	F	15.0	7.0
# 1	Spectab exclosure	378	11	12	1977	1	DO	M	33.0	48.0
# 1	Spectab exclosure	429	12	10	1977	1	DM	M	None	38.0
# 1	Spectab exclosure	440	12	10	1977	1	PF	F	16.0	7.0

# %%
join_surveys_plots = """
SELECT count(*)
FROM plots 
 INNER JOIN surveys ON plots.plot_id = surveys.plot_id;
"""

cursor.execute(join_surveys_plots)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# count(*)
# 35549

# %%
join_surveys_plots = """
SELECT plot_type, count(*)
FROM plots 
 INNER JOIN surveys ON plots.plot_id = surveys.plot_id
GROUP BY plot_type;
"""

cursor.execute(join_surveys_plots)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# plot_type	count(*)
# Control	15660
# Long-term Krat Exclosure	5259
# Rodent Exclosure	4744
# Short-term Krat Exclosure	5955
# Spectab exclosure	3931

# %%
join_surveys_plots = """
SELECT record_id ID, species, plots.plot_id, plot_type, year, month, day
FROM plots 
 INNER JOIN surveys ON plots.plot_id = surveys.plot_id
 INNER JOIN species ON species.species_id = surveys.species_id;
"""

cursor.execute(join_surveys_plots)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# ID	species	plot_id	plot_type	year	month	day
# 6	flavus	1	Spectab exclosure	1977	7	16
# 8	merriami	1	Spectab exclosure	1977	7	16
# 9	merriami	1	Spectab exclosure	1977	7	16
# 78	flavus	1	Spectab exclosure	1977	8	19
# 80	spectabilis	1	Spectab exclosure	1977	8	19
# 218	flavus	1	Spectab exclosure	1977	9	13
# 222	spectabilis	1	Spectab exclosure	1977	9	13
# 239	spectabilis	1	Spectab exclosure	1977	9	13
# 263	merriami	1	Spectab exclosure	1977	10	16
# 270	merriami	1	Spectab exclosure	1977	10	16
# 276	spectabilis	1	Spectab exclosure	1977	10	16
# 285	merriami	1	Spectab exclosure	1977	10	16
# 352	merriami	1	Spectab exclosure	1977	11	12
# 356	ordii	1	Spectab exclosure	1977	11	12
# 362	spectabilis	1	Spectab exclosure	1977	11	12
# 365	merriami	1	Spectab exclosure	1977	11	12
# 376	flavus	1	Spectab exclosure	1977	11	12
# 18200	eremicus	24	Rodent Exclosure	1991	1	11
# 18211	megalotis	24	Rodent Exclosure	1991	1	11
# 18220	megalotis	24	Rodent Exclosure	1991	1	11
# 18250	megalotis	24	Rodent Exclosure	1991	1	11
# 18316	ordii	24	Rodent Exclosure	1991	2	16
# 18327	ordii	24	Rodent Exclosure	1991	2	16
# 18356	megalotis	24	Rodent Exclosure	1991	2	16
# 18443	megalotis	24	Rodent Exclosure	1991	3	13
# 18448	megalotis	24	Rodent Exclosure	1991	3	13
# 18449	megalotis	24	Rodent Exclosure	1991	3	13
# 18484	leucogaster	24	Rodent Exclosure	1991	3	13
# 18577	megalotis	24	Rodent Exclosure	1991	4	19
# 18682	torridus	24	Rodent Exclosure	1991	5	13
# 18739	harrisi	24	Rodent Exclosure	1991	6	13
# 18753	megalotis	24	Rodent Exclosure	1991	6	13
# 18756	eremicus	24	Rodent Exclosure	1991	6	13
# 18758	albigula	24	Rodent Exclosure	1991	6	13
# 18767	megalotis	24	Rodent Exclosure	1991	6	13
# 18817	megalotis	24	Rodent Exclosure	1991	7	12
# 18820	eremicus	24	Rodent Exclosure	1991	7	12
# 18917	eremicus	24	Rodent Exclosure	1991	8	7
# 18939	eremicus	24	Rodent Exclosure	1991	8	7
# 18952	eremicus	24	Rodent Exclosure	1991	8	7
# 19047	torridus	24	Rodent Exclosure	1991	9	10
# 19055	harrisi	24	Rodent Exclosure	1991	9	10
# 19065	torridus	24	Rodent Exclosure	1991	9	10
# 19068	merriami	24	Rodent Exclosure	1991	9	10
# 19096	bilineata	24	Rodent Exclosure	1991	10	10
# 19100	eremicus	24	Rodent Exclosure	1991	10	10
# 19101	megalotis	24	Rodent Exclosure	1991	10	10
# 19273	megalotis	24	Rodent Exclosure	1991	11	14
# 19275	eremicus	24	Rodent Exclosure	1991	11	14
# 19288	megalotis	24	Rodent Exclosure	1991	11	14
# 19290	megalotis	24	Rodent Exclosure	1991	11	14
# 19295	megalotis	24	Rodent Exclosure	1991	11	14
# 19305	megalotis	24	Rodent Exclosure	1991	11	14
# 19381	megalotis	24	Rodent Exclosure	1991	12	7
# 19393	megalotis	24	Rodent Exclosure	1991	12	7
# 19400	eremicus	24	Rodent Exclosure	1991	12	7
# 19403	megalotis	24	Rodent Exclosure	1991	12	7
# 19415	megalotis	24	Rodent Exclosure	1991	12	7
# 19419	megalotis	24	Rodent Exclosure	1991	12	7
# 19428	eremicus	24	Rodent Exclosure	1991	12	7
# 19433	megalotis	24	Rodent Exclosure	1991	12	7
# 19445	megalotis	24	Rodent Exclosure	1991	12	7
# 19448	megalotis	24	Rodent Exclosure	1991	12	7
# 19550	megalotis	24	Rodent Exclosure	1992	1	8
# 19723	eremicus	24	Rodent Exclosure	1992	2	7
# 19728	leucogaster	24	Rodent Exclosure	1992	2	7
# 19731	eremicus	24	Rodent Exclosure	1992	2	7
# 19735	megalotis	24	Rodent Exclosure	1992	2	7
# 19777	megalotis	24	Rodent Exclosure	1992	3	7
# 19780	eremicus	24	Rodent Exclosure	1992	3	7
# 19805	megalotis	24	Rodent Exclosure	1992	3	7
# 19824	megalotis	24	Rodent Exclosure	1992	3	7
# 19878	leucogaster	24	Rodent Exclosure	1992	4	4
# 19887	eremicus	24	Rodent Exclosure	1992	4	4
# 19949	eremicus	24	Rodent Exclosure	1992	5	2
# 20011	eremicus	24	Rodent Exclosure	1992	5	30
# 20032	eremicus	24	Rodent Exclosure	1992	5	30
# 20187	megalotis	24	Rodent Exclosure	1992	7	30
# 20242	ochrognathus	24	Rodent Exclosure	1992	8	29
# 20274	harrisi	24	Rodent Exclosure	1992	8	29
# 20433	ochrognathus	24	Rodent Exclosure	1992	10	18
# 20460	harrisi	24	Rodent Exclosure	1992	10	18
# 20464	megalotis	24	Rodent Exclosure	1992	10	18
# 20525	megalotis	24	Rodent Exclosure	1992	12	21
# 20526	megalotis	24	Rodent Exclosure	1992	12	21
# 20532	megalotis	24	Rodent Exclosure	1992	12	21
# 20544	megalotis	24	Rodent Exclosure	1992	12	21
# 20583	eremicus	24	Rodent Exclosure	1993	1	24
# 20585	megalotis	24	Rodent Exclosure	1993	1	24
# 20642	megalotis	24	Rodent Exclosure	1993	2	19
# 20785	eremicus	24	Rodent Exclosure	1993	4	23
# 20899	eremicus	24	Rodent Exclosure	1993	6	18
# 20904	megalotis	24	Rodent Exclosure	1993	6	18
# 20906	eremicus	24	Rodent Exclosure	1993	6	18
# 20908	eremicus	24	Rodent Exclosure	1993	6	18
# 20996	eremicus	24	Rodent Exclosure	1993	7	14
# 20999	albigula	24	Rodent Exclosure	1993	7	14
# 21033	eremicus	24	Rodent Exclosure	1993	8	19
# 21043	megalotis	24	Rodent Exclosure	1993	8	19
# 21045	megalotis	24	Rodent Exclosure	1993	8	19
# 21049	megalotis	24	Rodent Exclosure	1993	8	19
# 21213	eremicus	24	Rodent Exclosure	1993	11	13
# 21219	eremicus	24	Rodent Exclosure	1993	11	13
# 21229	megalotis	24	Rodent Exclosure	1993	11	13
# 21272	megalotis	24	Rodent Exclosure	1993	12	14
# 21274	harrisi	24	Rodent Exclosure	1993	12	14
# 21342	fuscus	24	Rodent Exclosure	1994	2	1
# 21405	megalotis	24	Rodent Exclosure	1994	2	21
# 21454	megalotis	24	Rodent Exclosure	1994	3	11
# 21485	megalotis	24	Rodent Exclosure	1994	4	10
# 21557	ochrognathus	24	Rodent Exclosure	1994	5	18
# 21562	megalotis	24	Rodent Exclosure	1994	5	18
# 21576	megalotis	24	Rodent Exclosure	1994	5	18
# 21713	megalotis	24	Rodent Exclosure	1994	8	17
# 21881	eremicus	24	Rodent Exclosure	1994	11	1
# 21938	eremicus	24	Rodent Exclosure	1994	12	4
# 21939	eremicus	24	Rodent Exclosure	1994	12	4
# 21997	megalotis	24	Rodent Exclosure	1995	1	11
# 22046	megalotis	24	Rodent Exclosure	1995	2	4
# 22106	megalotis	24	Rodent Exclosure	1995	3	4
# 22232	megalotis	24	Rodent Exclosure	1995	4	29
# 22238	eremicus	24	Rodent Exclosure	1995	4	29
# 22298	eremicus	24	Rodent Exclosure	1995	6	7
# 22312	eremicus	24	Rodent Exclosure	1995	6	7
# 22313	eremicus	24	Rodent Exclosure	1995	6	7
# 22387	megalotis	24	Rodent Exclosure	1995	6	27
# 22476	albigula	24	Rodent Exclosure	1995	7	20
# 22558	megalotis	24	Rodent Exclosure	1995	8	26
# 22668	megalotis	24	Rodent Exclosure	1995	9	23
# 22687	megalotis	24	Rodent Exclosure	1995	9	23
# 22839	eremicus	24	Rodent Exclosure	1995	10	28
# 22841	eremicus	24	Rodent Exclosure	1995	10	28
# 22879	megalotis	24	Rodent Exclosure	1995	10	28
# 22892	megalotis	24	Rodent Exclosure	1995	10	28
# 23006	megalotis	24	Rodent Exclosure	1995	12	2
# 23017	megalotis	24	Rodent Exclosure	1995	12	2
# 23020	megalotis	24	Rodent Exclosure	1995	12	2
# 23021	maniculatus	24	Rodent Exclosure	1995	12	2
# 23135	leucopus	24	Rodent Exclosure	1995	12	21
# 23147	leucopus	24	Rodent Exclosure	1995	12	21
# 23219	leucopus	24	Rodent Exclosure	1996	1	27
# 23241	eremicus	24	Rodent Exclosure	1996	1	27
# 23244	megalotis	24	Rodent Exclosure	1996	1	27
# 23372	megalotis	24	Rodent Exclosure	1996	2	24
# 23387	maniculatus	24	Rodent Exclosure	1996	2	24
# 23513	maniculatus	24	Rodent Exclosure	1996	3	23
# 23515	megalotis	24	Rodent Exclosure	1996	3	23
# 23528	eremicus	24	Rodent Exclosure	1996	3	23
# 23557	megalotis	24	Rodent Exclosure	1996	3	23
# 23582	harrisi	24	Rodent Exclosure	1996	3	23
# 23660	maniculatus	24	Rodent Exclosure	1996	4	14
# 23664	megalotis	24	Rodent Exclosure	1996	4	14
# 23719	maniculatus	24	Rodent Exclosure	1996	4	14
# 23730	eremicus	24	Rodent Exclosure	1996	4	14
# 23897	megalotis	24	Rodent Exclosure	1996	5	23
# 24433	maniculatus	24	Rodent Exclosure	1996	9	21
# 24545	eremicus	24	Rodent Exclosure	1996	10	12
# 24552	eremicus	24	Rodent Exclosure	1996	10	12
# 24582	leucopus	24	Rodent Exclosure	1996	10	12
# 24689	maniculatus	24	Rodent Exclosure	1996	11	16
# 24802	maniculatus	24	Rodent Exclosure	1996	12	18
# 24809	megalotis	24	Rodent Exclosure	1996	12	18
# 24813	maniculatus	24	Rodent Exclosure	1996	12	18
# 24852	maniculatus	24	Rodent Exclosure	1996	12	18
# 24927	megalotis	24	Rodent Exclosure	1997	2	8
# 24937	maniculatus	24	Rodent Exclosure	1997	2	8
# 24953	eremicus	24	Rodent Exclosure	1997	2	8
# 24959	leucopus	24	Rodent Exclosure	1997	2	8
# 24987	leucopus	24	Rodent Exclosure	1997	2	8
# 25024	megalotis	24	Rodent Exclosure	1997	2	8
# 25182	eremicus	24	Rodent Exclosure	1997	3	15
# 25192	megalotis	24	Rodent Exclosure	1997	3	15
# 25199	maniculatus	24	Rodent Exclosure	1997	3	15
# 25230	eremicus	24	Rodent Exclosure	1997	3	15
# 25238	eremicus	24	Rodent Exclosure	1997	3	15
# 25441	megalotis	24	Rodent Exclosure	1997	4	12
# 25451	penicillatus	24	Rodent Exclosure	1997	4	12
# 27557	eremicus	24	Rodent Exclosure	1998	3	1
# 27569	maniculatus	24	Rodent Exclosure	1998	3	1
# 27573	megalotis	24	Rodent Exclosure	1998	3	1
# 27694	eremicus	24	Rodent Exclosure	1998	3	29
# 27724	eremicus	24	Rodent Exclosure	1998	3	29
# 27738	penicillatus	24	Rodent Exclosure	1998	3	29
# 27755	eremicus	24	Rodent Exclosure	1998	5	2
# 27767	eremicus	24	Rodent Exclosure	1998	5	2
# 27799	maniculatus	24	Rodent Exclosure	1998	5	2
# 27859	eremicus	24	Rodent Exclosure	1998	5	28
# 27926	albigula	24	Rodent Exclosure	1998	5	28
# 28016	penicillatus	24	Rodent Exclosure	1998	6	27
# 28032	albigula	24	Rodent Exclosure	1998	6	27
# 28058	eremicus	24	Rodent Exclosure	1998	6	27
# 28064	eremicus	24	Rodent Exclosure	1998	6	27
# 28085	eremicus	24	Rodent Exclosure	1998	6	27
# 28175	penicillatus	24	Rodent Exclosure	1998	7	18
# 28218	eremicus	24	Rodent Exclosure	1998	7	18
# 28219	eremicus	24	Rodent Exclosure	1998	7	18
# 28402	maniculatus	24	Rodent Exclosure	1998	8	22
# 28403	eremicus	24	Rodent Exclosure	1998	8	22
# 28534	merriami	24	Rodent Exclosure	1998	9	19
# 28535	eremicus	24	Rodent Exclosure	1998	9	19
# 28536	eremicus	24	Rodent Exclosure	1998	9	19
# 28729	baileyi	24	Rodent Exclosure	1998	10	24
# 28730	albigula	24	Rodent Exclosure	1998	10	24
# 28731	maniculatus	24	Rodent Exclosure	1998	10	24
# 28732	maniculatus	24	Rodent Exclosure	1998	10	24
# 28733	maniculatus	24	Rodent Exclosure	1998	10	24
# 28862	albigula	24	Rodent Exclosure	1998	11	21
# 28863	maniculatus	24	Rodent Exclosure	1998	11	21
# 28971	maniculatus	24	Rodent Exclosure	1998	12	22
# 29089	penicillatus	24	Rodent Exclosure	1999	1	16
# 29368	megalotis	24	Rodent Exclosure	1999	3	14
# 29490	maniculatus	24	Rodent Exclosure	1999	4	17
# 29624	maniculatus	24	Rodent Exclosure	1999	5	15
# 29625	maniculatus	24	Rodent Exclosure	1999	5	15
# 29761	maniculatus	24	Rodent Exclosure	1999	6	12
# 29762	eremicus	24	Rodent Exclosure	1999	6	12
# 29763	maniculatus	24	Rodent Exclosure	1999	6	12
# 29834	albigula	24	Rodent Exclosure	1999	9	11
# 29897	eremicus	24	Rodent Exclosure	1999	10	9
# 29993	penicillatus	24	Rodent Exclosure	1999	11	6
# 29994	albigula	24	Rodent Exclosure	1999	11	6
# 30219	megalotis	24	Rodent Exclosure	2000	1	8
# 30353	baileyi	24	Rodent Exclosure	2000	2	5
# 30354	baileyi	24	Rodent Exclosure	2000	2	5
# 30497	penicillatus	24	Rodent Exclosure	2000	3	4
# 30498	penicillatus	24	Rodent Exclosure	2000	3	4
# 30499	leucopus	24	Rodent Exclosure	2000	3	4
# 30644	eremicus	24	Rodent Exclosure	2000	4	30
# 30645	eremicus	24	Rodent Exclosure	2000	4	30
# 30646	penicillatus	24	Rodent Exclosure	2000	4	30
# 34529	albigula	24	Rodent Exclosure	2002	7	13
# 34530	hispidus	24	Rodent Exclosure	2002	7	13
# 34531	albigula	24	Rodent Exclosure	2002	7	13
# 34697	penicillatus	24	Rodent Exclosure	2002	9	8
# 34864	albigula	24	Rodent Exclosure	2002	10	5
# 34865	eremicus	24	Rodent Exclosure	2002	10	5
# 34866	eremicus	24	Rodent Exclosure	2002	10	5
# 35068	megalotis	24	Rodent Exclosure	2002	11	9
# 35069	baileyi	24	Rodent Exclosure	2002	11	9
# 35070	eremicus	24	Rodent Exclosure	2002	11	9
# 35071	eremicus	24	Rodent Exclosure	2002	11	9
# 35072	baileyi	24	Rodent Exclosure	2002	11	9
# 35283	eremicus	24	Rodent Exclosure	2002	12	7
# 35284	albigula	24	Rodent Exclosure	2002	12	7
# 35478	harrisi	24	Rodent Exclosure	2002	12	29
# 35479	albigula	24	Rodent Exclosure	2002	12	29

# %% [markdown]
# #### See the create table statement

# %%
# sql column in the sqlite_master table

sql = '''
SELECT sql
FROM sqlite_master 
WHERE type= "table" and name == "species"
LIMIT 2;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# sql
# CREATE TABLE species (
# 	species_id TEXT,
# 	genus TEXT,
# 	species TEXT,
# 	taxa TEXT
# )

# %%
sql ="""
CREATE TABLE species (
	species_id TEXT, 
	genus TEXT, 
	species TEXT, 
	taxa TEXT
)"""
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [67], in <cell line: 8>()
#       1 sql ="""
#       2 CREATE TABLE species (
#       3 	species_id TEXT,
#    (...)
#       6 	taxa TEXT
#       7 )"""
# ----> 8 cursor.execute(sql)
#
# OperationalError: table species already exists

# %% [markdown]
# ___
#
# ### CREATE TABLE  - statement
# ##### <font color="red"> This statement makes changes to the database</font>
#
#
# https://www.sqlitetutorial.net/sqlite-create-table/
#
# ```sql
# CREATE TABLE [IF NOT EXISTS] [schema_name].table_name (
#     column_1 data_type PRIMARY KEY,
#     column_2 data_type NOT NULL,
#     column_3 data_type DEFAULT 0,
#     table_constraints
# ) [WITHOUT ROWID];
# ```
#
# In this syntax:
#
# * First, specify the name of the table that you want to create after the CREATE TABLE keywords. The name of the table cannot start with sqlite_ because it is reserved for the internal use of SQLite.
# * Second, use `IF NOT EXISTS` option to create a new table if it does not exist. Attempting to create a table that already exists without using the IF NOT EXISTS option will result in an error.
# * Third, optionally specify the schema_name to which the new table belongs. The schema can be the main database, temp database or any attached database.
# * Fourth, specify the column list of the table. Each column has a name, data type, and the column constraint. SQLite supports `PRIMARY KEY, UNIQUE, NOT NULL`, and `CHECK` column constraints.
# * Fifth, specify the table constraints such as PRIMARY KEY, FOREIGN KEY, UNIQUE, and CHECK constraints.
# * Finally, optionally use the `WITHOUT ROWID` option. By default, a row in a table has an implicit column, which is referred to as the rowid, oid or _rowid_ column. The rowid column stores a 64-bit signed integer key that uniquely identifies the row inside the table. If you don’t want SQLite creates the rowid column, you specify the WITHOUT ROWID option. A table that contains the rowid column is known as a rowid table. Note that the WITHOUT ROWID option is only available in SQLite 3.8.2 or later.

# %% [markdown]
# https://www.sqlite.org/syntaxdiagrams.html#create-table-stmt
#
# <img src = "https://www.sqlite.org/images/syntax/create-table-stmt.gif" width="800"/>

# %% [markdown]
# Each value stored in an SQLite database (or manipulated by the database engine) has one of the following storage classes:
# https://www.sqlite.org/datatype3.html
# * `NULL`. The value is a NULL value.
# * `INTEGER`. The value is a signed integer, stored in 1, 2, 3, 4, 6, or 8 bytes depending on the magnitude of the value.
# * `REAL`. The value is a floating point value, stored as an 8-byte IEEE floating point number.
# * `TEXT`. The value is a text string, stored using the database encoding (UTF-8, UTF-16BE or UTF-16LE).
# * `BLOB`. The value is a blob of data, stored exactly as it was input.

# %% [markdown]
# #### A `PRIMARY KEY` is a very important concept to understand.
# * It is the designation for a column or a set of columns from a table.
# * It is recommended to be a serial value and not something related to the business needs of the data in the table.
#
# * A primary key is used to uniquely identify a row of data; combined with a column name, uniquely locates a data entry
# * A primary key by definition must be `UNIQUE` and `NOT NULL`
# * The primary key of a table, should be a (sequential) non-repeating and not null value
# * Primary keys are generally identified at time of table creation
# * A common method for generating a primary key, is to set the datatype to `INTEGER` and declare `AUTOINCREMENT` which will function when data is inserted into the table
# * Primary keys can be a composite of 2 or more columns that uniquely identify the data in the table

# %% [markdown]
# #### A `FOREIGN KEY` is a column(s) that points to the `PRIMARY KEY` of another table
#
# * The purpose of the foreign key is to ensure referential integrity of the data.
# In other words, only values that are supposed to appear in the database are permitted.<br>
# Only the values that exist in the `PRIMARY KEY` column are allowed to be present in the FOREIGN KEY column.
# Example: A `gene` table has the `PRIMARY KEY` `gene_id`. The GO2_gene GO term is associated with a gene
#
# They are also the underpinning of how tables are joined and relationships portrayed in the database

# %% [markdown]
# The `sqlite_master` has the following create statement:
# ```sql
# CREATE TABLE sqlite_master ( type TEXT, name TEXT, tbl_name TEXT, rootpage INTEGER, sql TEXT );
# ```

# %% [markdown]
# ##### The `connection` object methods can be used to save or revert/reset the changes after a command that makes changes to the database
# ##### `COMMIT` - save the changes
# ##### `ROLLBACK` - revert the changes

# %%
# select the sql statement for the survey table

sql = '''
SELECT sql
FROM sqlite_master 
WHERE name = "surveys";
'''
cursor.execute(sql)

# fetchall returns a list of tuples, 
# we want the first element in the list 
# and then the first element in the tuple

print(cursor.fetchall()[0][0])
# Out:
# CREATE TABLE surveys (
# 	record_id BIGINT,
# 	month BIGINT,
# 	day BIGINT,
# 	year BIGINT,
# 	plot_id BIGINT,
# 	species_id TEXT,
# 	sex TEXT,
# 	hindfoot_length FLOAT,
# 	weight FLOAT
# )

# %% [markdown]
# #### We create the table `survey_summary` with the columns: `id`, `species_id`, `year`, and `count`

# %%
# Write and run a create table statement for the survey_summary table

sql='''
CREATE TABLE IF NOT EXISTS survey_summary (
      id INTEGER PRIMARY KEY AUTOINCREMENT,
      species_id TEXT NOT NULL,                    -- REFERENCES  species_id in species table
      year INT NOT NULL,                      -- year of the survey
      count BIGINT NOT NULL,                 -- number of sightings of the species id in the respective year
      FOREIGN KEY (species_id) REFERENCES  species  (species_id)
    );
'''
try:
    cursor.execute(sql)
except connection.DatabaseError:
    print("Creating the survey_summary table resulted in a database error!")
    connection.rollback()
    raise
else:
    connection.commit()
finally:
    print("done!")
# Out:
# done!

# %% [markdown]
# ##### Similar error handling, as seen above, can be when executing any statement that changes the database.

# %% [markdown]
# ##### Check if the new table appears in the `sqlite_master` table

# %%
sql = '''
SELECT name
FROM sqlite_master 
WHERE name LIKE "su%"
LIMIT 4;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [('surveys',), ('survey_summary',)]

# %% [markdown]
#
# <br><br>
# The `sqlite_sequence` table is created and initialized automatically whenever a regular table is created if it has a column with the `AUTOINCREMENT` option set.<br>
# https://www.sqlite.org/autoinc.html

# %% [markdown]
# ##### Check if the new table appears in the `sqlite_master` table

# %%
sql = '''
SELECT name
FROM sqlite_master;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [('surveys',), ('species',), ('plots',), ('survey_summary',), ('sqlite_sequence',)]

# %%
# the sqlite_sequence records keep track of the autoincrement column form different tables
# by storing the value where the autoincrement is currently
# if there was no data added in the table, no record exists in the sqlite_sequence table

sql = '''
SELECT *
FROM sqlite_sequence;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# []

# %%
select_survey_summary = """
SELECT *
FROM survey_summary;
"""

cursor.execute(select_survey_summary)
cursor.fetchall()
# Out:
# []

# %% [markdown]
# ____
# ### INDEXING
#
# Indexes are lookup table, like the index of a book.
# They are usually created for columns that have unique/ or less redundant values and provide a way to quicky search
# the values.<br>
# Indexing creates a copy of the indexed columns together with a link to the location of the additional information.<br>
# The index data is stored in a data structure that allows for fast sorting. <br>
# E.g.: balanced-tree - every leaf is at most n nodes away from the root) that allows for fast sorting. <br>
# All queries (statements) regarding an indexed table are applied to the index
#
#
# * One important function in Relational Databases is to be able to create indexes on columns in tables
# * These indexes are pre-calculated and stored in the database
# * Indexes should be created on columns that are used in queries and joins
# * They will rapidly speed up query return rate and improve query performance
#
# To create an index use the following command:
#
# ```sql
# CREATE INDEX indexName ON tableName (columnName)
# ```

# %%
sql = '''
CREATE INDEX survey_summary_idx 
ON survey_summary (species_id)
'''
cursor.execute(sql)
connection.commit()

# %% [markdown]
# ##### Check if the new index appears in the `sqlite_master` table

# %%
sql = '''
SELECT name, sql
FROM sqlite_master 
WHERE type= "index";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name	sql
# survey_summary_idx	CREATE INDEX survey_summary_idx
# ON survey_summary (species_id)

# %%
sql = '''
SELECT name, type
FROM sqlite_master; 

'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name	type
# surveys	table
# species	table
# plots	table
# survey_summary	table
# sqlite_sequence	table
# survey_summary_idx	index

# %% [markdown]
# #### Remove the index

# %%
sql = '''
DROP INDEX survey_summary_idx 
'''
cursor.execute(sql)
connection.commit()

# %% [markdown]
# ##### Check if the index was removed from the `sqlite_master` table

# %%
sql = '''
SELECT name
FROM sqlite_master 
--WHERE type= "index";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name
# surveys
# species
# plots
# survey_summary
# sqlite_sequence

# %% [markdown]
# ____
#
# ### INSERT - statement
#
# ##### <font color="red"> This statement makes changes to the database</font>
# Adds new data to a table (if the constraints are met)
# Constraint examples:
# * For one designated column or a group of columns that are designated as Primary Key the values are unique
# * The value inserted in a column that has a Foreign Key constraint should exist in the column that it refers to
#
# ```sql
# INSERT INTO <tablename> (<column1>, <column2>, <column3>) VALUES (value1, value2, value3);
# ```
#
# ##### One simple INSERT command adds 1 row of data at a time into an existing table
#
# ##### Connection object allows us to:
# * ##### COMMIT - save the changes
# * ##### ROLLBACK - reverts/discards the changes

# %% [markdown]
# <br>
#
# ##### Let's see what is in the table (it should be nothing):

# %%
sql = '''
SELECT *
FROM survey_summary;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count

# %% [markdown]
# <br>
#
# ##### Let's try an insert:
# ```sql
# INSERT INTO <tablename> (<column1>, <column2>, <column3>) VALUES (value1, value2, value3);
# ```

# %%
sql = '''
INSERT INTO survey_summary (species_id, year, count) 
VALUES ("SPECIES1",1995,4);
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4

# %%
sql = '''
INSERT INTO survey_summary (species_id, year, count) 
VALUES ("SPECIES2",1996,14);
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14

# %%
values_list = ["DM",1960, 0]

sql = '''
INSERT INTO survey_summary (species_id, year, count) 
VALUES (?,?,?);
'''
cursor.execute(sql,values_list)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0

# %%
# This command retrieves the identifier of the last row from the most current query
# The gene_go_id

id_value = cursor.lastrowid
id_value
# Out:
# 3

# %%
# the record in sqlite_sequence keep track of the autoincrement
sql = '''
SELECT *
FROM sqlite_sequence;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [('survey_summary', 3)]

# %%
values_list = [7, "DM",1970, 10]

sql = '''
INSERT INTO survey_summary (id, species_id, year, count) 
VALUES (?,?,?,?);
'''
cursor.execute(sql,values_list)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0
# 7	DM	1970	10

# %%
sql = '''
SELECT *
FROM sqlite_sequence;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [('survey_summary', 7)]

# %%
values_list = [7, "DM",1970, 10]

sql = '''
INSERT INTO survey_summary (id, species_id, year, count) 
VALUES (?,?,?,?);
'''
cursor.execute(sql,values_list)
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Input In [95], in <cell line: 7>()
#       1 values_list = [7, "DM",1970, 10]
#       3 sql = '''
#       4 INSERT INTO survey_summary (id, species_id, year, count)
#       5 VALUES (?,?,?,?);
#       6 '''
# ----> 7 cursor.execute(sql,values_list)
#       8 connection.commit()
#
# IntegrityError: UNIQUE constraint failed: survey_summary.id

# %% [markdown]
# <br>
#
#
# ##### We have a row in the table!!! And the gene_go_id was automatically generated.

# %%
sql = '''
SELECT *
FROM survey_summary ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0
# 7	DM	1970	10

# %% [markdown]
# #### You can have a Python "table" structure (list of lists) of insert values and get them all inserted in one command, each sublist having the correct number of values.

# %%
values_tbl = [["TEST",1950,2], ["TEST",1955,1], ["TEST",1974,2]]

sql = '''
INSERT INTO survey_summary (species_id, year, count) 
VALUES (?,?,?);
'''
cursor.executemany(sql,values_tbl)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0
# 7	DM	1970	10
# 8	TEST	1950	2
# 9	TEST	1955	1
# 10	TEST	1974	2

# %% [markdown]
# ____
#
# #### UPDATE - statement - changes the table rows

# %% [markdown]
# ##### <font color="red"> This statement makes changes to the database</font>
#
# MODIFIES DATA (already in a table)  in all rows matching the WHERE clause
#
# ```sql
# UPDATE table_name
# SET column1 = value1, column2 = value2...., columnN = valueN
# WHERE [condition];
# ```
#
# Update is generally a single row command, but use of the where clause can cause data to be updated in multiple rows <br>
# (whether you intended to or not !!!!)
#
# The following statement updates the evidence for all entries for all genes associated with the 2 biological processses

# %%
sql = '''
SELECT * 
FROM survey_summary
WHERE species_id = "TEST";
'''
cursor.execute(sql)
# cursor.fetchall()
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 8	TEST	1950	2
# 9	TEST	1955	1
# 10	TEST	1974	2

# %%
# the following statement updates multiple rows
# before an update a select on the same table and 
# with the same where clause should be ran 
# to see the records that will be updated

sql = '''
UPDATE survey_summary
SET count = 20 
WHERE species_id = "TEST";
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0
# 7	DM	1970	10
# 8	TEST	1950	20
# 9	TEST	1955	20
# 10	TEST	1974	20

# %%
sql = '''
UPDATE survey_summary
SET count = 15 
WHERE 
    species_id = "TEST" AND
    year = 1950;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0
# 7	DM	1970	10
# 8	TEST	1950	15
# 9	TEST	1955	20
# 10	TEST	1974	20

# %% [markdown]
# ___
#
# #### DELETE - statement - deletes table rows
#
# * MAKES CHANGES TO THE DATA
# * Row level deletion – can’t delete less than this.
#
# ```sql
# DELETE FROM <tablename> WHERE <column> = <value>
# ```
#
# * The WHERE predicate is the same as for the SELECT statement, that is, it determines which rows will be deleted

# %%
sql = '''
SELECT * 
FROM survey_summary 
WHERE year < 1960;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 8	TEST	1950	15
# 9	TEST	1955	20

# %%
# before a delete statement a select on the same table and 
# with the same where clause should be ran to see the records 
# that will be removed

sql = '''
DELETE FROM survey_summary 
WHERE year < 1960;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count
# 1	SPECIES1	1995	4
# 2	SPECIES2	1996	14
# 3	DM	1960	0
# 7	DM	1970	10
# 10	TEST	1974	20

# %% [markdown]
# ```sql
# DELETE FROM <tablename>;
# ```
#
# * This would delete all rows of data from a table.
# * Preserves table structure (table still exists)
# * Optimized for speed in SQLite, no row-by-row execution.
# * EXISTS <table_name> still evaluates to True

# %%
# Delete all data from the table - but keep the table 

sql = '''
DELETE FROM survey_summary;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM survey_summary ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# id	species_id	year	count

# %% [markdown]
# <br>
#
# #### `DROP TABLE` - statement - removes a table (permanently)

# %%
sql = '''
DROP TABLE IF EXISTS survey_summary;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT name AS "TABLE NAME"
FROM sqlite_master;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# TABLE NAME
# surveys
# species
# plots
# sqlite_sequence

# %%
# we can create the summary with a select

sql = '''

SELECT species_id, year, count(record_id)
FROM surveys 
WHERE species_id <> "None"
GROUP BY species_id, year;'''
cursor.execute(sql)
#cursor.fetchall()
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	year	count(record_id)
# AB	1980	5
# AB	1981	7
# AB	1982	34
# AB	1983	41
# AB	1984	12
# AB	1985	14
# AB	1986	5
# AB	1987	35
# AB	1988	39
# AB	1989	31
# AB	1990	27
# AB	1991	15
# AB	1992	10
# AB	1993	9
# AB	1994	7
# AB	1995	4
# AB	1998	2
# AB	2000	3
# AB	2001	1
# AB	2002	2
# AH	1978	1
# AH	1982	1
# AH	1983	2
# AH	1984	2
# AH	1985	14
# AH	1986	19
# AH	1987	41
# AH	1988	26
# AH	1989	30
# AH	1990	22
# AH	1991	21
# AH	1992	16
# AH	1993	15
# AH	1994	19
# AH	1995	36
# AH	1996	25
# AH	1997	37
# AH	1998	33
# AH	1999	14
# AH	2000	12
# AH	2001	23
# AH	2002	28
# AS	1991	1
# AS	1993	1
# BA	1989	3
# BA	1990	11
# BA	1991	26
# BA	1992	6
# CB	1980	1
# CB	1981	1
# CB	1983	3
# CB	1984	1
# CB	1985	1
# CB	1986	4
# CB	1987	5
# CB	1988	6
# CB	1989	1
# CB	1991	2
# CB	1992	7
# CB	1993	5
# CB	1994	1
# CB	1995	2
# CB	1997	3
# CB	1998	4
# CB	2001	3
# CM	1980	12
# CM	1987	1
# CQ	1980	2
# CQ	1981	4
# CQ	1982	8
# CQ	1984	2
# CS	1989	1
# CT	1998	1
# CU	1993	1
# CV	1987	1
# DM	1977	264
# DM	1978	389
# DM	1979	209
# DM	1980	493
# DM	1981	559
# DM	1982	609
# DM	1983	528
# DM	1984	396
# DM	1985	667
# DM	1986	406
# DM	1987	469
# DM	1988	365
# DM	1989	321
# DM	1990	462
# DM	1991	404
# DM	1992	307
# DM	1993	253
# DM	1994	293
# DM	1995	436
# DM	1996	492
# DM	1997	576
# DM	1998	503
# DM	1999	348
# DM	2000	233
# DM	2001	305
# DM	2002	309
# DO	1977	12
# DO	1978	22
# DO	1979	31
# DO	1980	89
# DO	1981	123
# DO	1982	117
# DO	1983	167
# DO	1984	108
# DO	1985	225
# DO	1986	115
# DO	1987	213
# DO	1988	144
# DO	1989	119
# DO	1990	171
# DO	1991	122
# DO	1992	94
# DO	1993	29
# DO	1994	25
# DO	1995	58
# DO	1996	174
# DO	1997	253
# DO	1998	111
# DO	1999	84
# DO	2000	91
# DO	2001	81
# DO	2002	249
# DS	1977	98
# DS	1978	320
# DS	1979	204
# DS	1980	346
# DS	1981	354
# DS	1982	354
# DS	1983	280
# DS	1984	76
# DS	1985	98
# DS	1986	88
# DS	1987	104
# DS	1988	54
# DS	1989	33
# DS	1990	17
# DS	1991	11
# DS	1992	18
# DS	1993	18
# DS	1994	9
# DS	1997	6
# DS	1998	9
# DS	1999	7
# DX	1980	1
# DX	1983	1
# DX	1986	1
# DX	1988	1
# DX	1991	4
# DX	1992	12
# DX	1993	3
# DX	1994	2
# DX	1995	3
# DX	1996	1
# DX	1998	2
# DX	1999	3
# DX	2000	4
# DX	2001	1
# DX	2002	1
# NL	1977	31
# NL	1978	48
# NL	1979	30
# NL	1980	57
# NL	1981	63
# NL	1982	111
# NL	1983	98
# NL	1984	64
# NL	1985	45
# NL	1986	60
# NL	1987	128
# NL	1988	102
# NL	1989	67
# NL	1990	29
# NL	1991	30
# NL	1992	15
# NL	1993	24
# NL	1994	10
# NL	1995	8
# NL	1996	7
# NL	1997	48
# NL	1998	32
# NL	1999	20
# NL	2000	29
# NL	2001	48
# NL	2002	48
# OL	1977	10
# OL	1978	47
# OL	1979	46
# OL	1980	85
# OL	1981	55
# OL	1982	83
# OL	1983	65
# OL	1984	71
# OL	1985	94
# OL	1986	43
# OL	1987	79
# OL	1988	51
# OL	1989	57
# OL	1990	25
# OL	1991	36
# OL	1992	45
# OL	1993	35
# OL	1994	21
# OL	1995	29
# OL	1996	13
# OL	1997	8
# OL	2002	8
# OT	1977	17
# OT	1978	66
# OT	1979	68
# OT	1980	96
# OT	1981	65
# OT	1982	94
# OT	1983	86
# OT	1984	49
# OT	1985	62
# OT	1986	25
# OT	1987	43
# OT	1988	86
# OT	1989	102
# OT	1990	77
# OT	1991	107
# OT	1992	42
# OT	1993	22
# OT	1994	21
# OT	1995	38
# OT	1996	108
# OT	1997	258
# OT	1998	164
# OT	1999	105
# OT	2000	154
# OT	2001	167
# OT	2002	127
# OX	1977	7
# OX	1978	1
# OX	1982	1
# OX	1984	1
# OX	1989	1
# OX	1993	1
# PB	1995	7
# PB	1996	39
# PB	1997	259
# PB	1998	329
# PB	1999	272
# PB	2000	555
# PB	2001	538
# PB	2002	892
# PC	1982	2
# PC	1983	3
# PC	1987	5
# PC	1989	1
# PC	1990	8
# PC	1991	6
# PC	1992	9
# PC	1993	1
# PC	1994	1
# PC	1995	1
# PC	1996	1
# PC	1998	1
# PE	1977	6
# PE	1978	17
# PE	1979	17
# PE	1980	20
# PE	1981	43
# PE	1982	107
# PE	1983	38
# PE	1984	20
# PE	1985	51
# PE	1986	26
# PE	1987	142
# PE	1988	190
# PE	1989	177
# PE	1990	75
# PE	1991	65
# PE	1992	41
# PE	1993	13
# PE	1994	3
# PE	1995	14
# PE	1996	36
# PE	1997	57
# PE	1998	24
# PE	1999	7
# PE	2000	15
# PE	2001	35
# PE	2002	60
# PF	1977	31
# PF	1978	40
# PF	1979	19
# PF	1980	95
# PF	1981	59
# PF	1982	152
# PF	1983	114
# PF	1984	7
# PF	1985	1
# PF	1986	2
# PF	1987	4
# PF	1988	2
# PF	1989	13
# PF	1990	51
# PF	1991	62
# PF	1992	57
# PF	1993	70
# PF	1994	73
# PF	1995	158
# PF	1996	330
# PF	1997	186
# PF	1998	26
# PF	2001	27
# PF	2002	18
# PG	1983	1
# PG	1988	2
# PG	1990	4
# PG	2000	1
# PH	1984	7
# PH	1985	3
# PH	1986	1
# PH	1988	1
# PH	1989	2
# PH	1990	7
# PH	1992	7
# PH	1995	3
# PH	1997	1
# PI	1992	1
# PI	1995	1
# PI	2001	2
# PI	2002	5
# PL	1995	3
# PL	1996	6
# PL	1997	19
# PL	1998	7
# PL	2000	1
# PM	1978	3
# PM	1979	6
# PM	1980	1
# PM	1981	16
# PM	1982	72
# PM	1983	42
# PM	1984	12
# PM	1985	17
# PM	1986	34
# PM	1987	133
# PM	1988	54
# PM	1989	27
# PM	1995	8
# PM	1996	50
# PM	1997	271
# PM	1998	103
# PM	1999	44
# PM	2000	2
# PM	2001	3
# PM	2002	1
# PP	1977	7
# PP	1978	24
# PP	1979	20
# PP	1980	17
# PP	1981	20
# PP	1982	32
# PP	1983	32
# PP	1984	26
# PP	1985	35
# PP	1986	26
# PP	1987	45
# PP	1988	53
# PP	1989	45
# PP	1990	34
# PP	1991	88
# PP	1992	131
# PP	1993	100
# PP	1994	74
# PP	1995	277
# PP	1996	298
# PP	1997	325
# PP	1998	208
# PP	1999	167
# PP	2000	381
# PP	2001	273
# PP	2002	385
# PU	1984	2
# PU	1994	2
# PU	1995	1
# PX	1996	2
# PX	1997	2
# PX	1998	1
# PX	2000	1
# RF	1982	2
# RF	1988	11
# RF	1989	49
# RF	1990	12
# RF	1997	1
# RM	1977	2
# RM	1978	3
# RM	1979	6
# RM	1980	46
# RM	1981	29
# RM	1982	154
# RM	1983	127
# RM	1984	60
# RM	1985	72
# RM	1986	53
# RM	1987	189
# RM	1988	211
# RM	1989	398
# RM	1990	231
# RM	1991	307
# RM	1992	158
# RM	1993	103
# RM	1994	40
# RM	1995	81
# RM	1996	90
# RM	1997	158
# RM	1998	13
# RM	1999	28
# RM	2000	15
# RM	2001	15
# RM	2002	20
# RO	1991	1
# RO	2002	7
# RX	1995	1
# RX	1997	1
# SA	1978	2
# SA	1981	11
# SA	1982	17
# SA	1983	10
# SA	1984	20
# SA	1985	3
# SA	1986	1
# SA	1987	1
# SA	1988	1
# SA	1989	3
# SA	1991	2
# SA	1996	1
# SA	1997	1
# SA	1998	2
# SC	1989	1
# SF	1989	5
# SF	1990	18
# SF	1991	7
# SF	1992	3
# SF	1993	3
# SF	2002	7
# SH	1977	1
# SH	1978	1
# SH	1982	2
# SH	1983	2
# SH	1986	1
# SH	1987	5
# SH	1988	31
# SH	1989	55
# SH	1990	9
# SH	1991	1
# SH	1997	7
# SH	1999	2
# SH	2000	8
# SH	2001	11
# SH	2002	11
# SO	1991	11
# SO	1992	20
# SO	1993	6
# SO	1994	3
# SO	1997	3
# SS	1977	1
# SS	1978	8
# SS	1979	2
# SS	1980	9
# SS	1981	8
# SS	1982	12
# SS	1983	12
# SS	1984	15
# SS	1985	14
# SS	1986	12
# SS	1987	20
# SS	1988	20
# SS	1989	18
# SS	1990	5
# SS	1991	2
# SS	1992	7
# SS	1993	1
# SS	1994	7
# SS	1995	7
# SS	1996	16
# SS	1997	12
# SS	1998	15
# SS	1999	7
# SS	2000	4
# SS	2001	5
# SS	2002	9
# ST	1993	1
# SU	1994	1
# SU	1995	4
# UL	1988	1
# UL	1992	1
# UL	1994	2
# UP	1987	2
# UP	1988	3
# UP	1989	2
# UP	1990	1
# UR	1987	3
# UR	1988	1
# UR	1991	1
# UR	1992	1
# UR	1994	1
# UR	2001	2
# UR	2002	1
# US	2002	4
# ZL	1988	2

# %% [markdown]
# #### VIEW in a database
#
# * A view is a virtual table which can be created from a query on existing tables
# * Views are created to give a more human readable version of the normalized data / tables
# * http://www.sqlitetutorial.net/sqlite-create-view/
# * An SQLite view is read only

# %% [markdown]
# ```sql
# CREATE [TEMP] VIEW [IF NOT EXISTS] view_name(column-name-list) AS
# select-statement;
# ```

# %%
# survey summary for years > 80 information for easy access
sql = '''
CREATE VIEW IF NOT EXISTS species_survey(species_id, species, year, counts) AS

SELECT sv.species_id, species, year, count(record_id)
FROM surveys AS sv
    INNER JOIN species AS sp ON sv.species_id = sp.species_id
WHERE sv.species_id <> "None"
GROUP BY sv.species_id,species, year


'''
cursor.execute(sql)
connection.commit()

# %%
# gene go information 
sql = '''
SELECT *
FROM species_survey
LIMIT 10;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# species_id	species	year	counts
# AB	bilineata	1980	5
# AB	bilineata	1981	7
# AB	bilineata	1982	34
# AB	bilineata	1983	41
# AB	bilineata	1984	12
# AB	bilineata	1985	14
# AB	bilineata	1986	5
# AB	bilineata	1987	35
# AB	bilineata	1988	39
# AB	bilineata	1989	31

# %%
sql = '''
SELECT name, type
FROM sqlite_master;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name	type
# surveys	table
# species	table
# plots	table
# sqlite_sequence	table
# species_survey	view

# %% [markdown]
# ```sql
# DROP VIEW [IF EXISTS] view_name;
# ```

# %%
# remove view from the database

sql = '''
DROP VIEW IF EXISTS species_survey;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT name, type
FROM sqlite_master;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name	type
# surveys	table
# species	table
# plots	table
# sqlite_sequence	table

# %%
# And close()

cursor.close()
connection.close()

# %%
cursor.execute("SELECT * FROM sqlite_master;")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [120], in <cell line: 1>()
# ----> 1 cursor.execute("SELECT * FROM sqlite_master;")
#
# ProgrammingError: Cannot operate on a closed cursor.

# %% [markdown]
# #### To remove the database, delete the .sqlite file.

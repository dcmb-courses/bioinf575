# %% [markdown]
# ## Homework 5 - Data structures and control structures
# ### BIOINF 575
#
# #### Total 100 points

# %% [markdown]
# For each each problem part provide the solution in Code cells after the description of the problem part.
# Answers to questions should be written either as comments together with the code or in Markdown cell(s) for each part of the problem.
#
# This homework will require the use of data structures, control structures, functions and reading from files and writing to files.

# %% [markdown]
# ______
#
# ### Problem 1 - Exploring biological networks
# #### 20 points

# %% [markdown]
# Transcription networks contain a small set of recurring regulation patterns, called network motifs.
# Here are some references about network motifs in biological networks.
# https://www.nature.com/articles/nrg2102
# https://link.springer.com/referenceworkentry/10.1007%2F978-1-4419-9863-7_463
# https://media.springernature.com/lw785/springer-static/image/prt%3A978-1-4419-9863-7%2F6/MediaObjects/978-1-4419-9863-7_6_Part_Fig1-463_HTML.gif
#
# Feed forward loop (A) - small recurring pattern (B and C show the two parts of the FFL):
# <img src = https://www.frontiersin.org/files/Articles/222083/fphys-07-00600-HTML/image_m/fphys-07-00600-g001.jpg width = 200/>
# <img src = Gli_network.png width = 500/>
#
#
# https://www.frontiersin.org/articles/10.3389/fphys.2016.00600/full

# %% [markdown]
# ..................................................................................................
#
# #### Part 1 (10 points) - Exploring network motifs
#
# - Write code that computes the set of feed-forward loops available in a given bilogical network.
# - A feed forward loop will be represented as a tuple of three nodes (genes ot transcription factors).
#     - E.g. ("X", "Y" ,"Z") is a feed-forward loop (FFL) if there is an edge from "X" to "Y", and from "Y" to "Z", and from "X" to "Z"
#
# - <b>Score breakdown:</b>
#     - <b>(5 points)</b> Code that finds X->Y->Z groups
#     - <b>(5 points)</b> Code that makes sure that there is a X->Z relation in addition to the X->Y->Z

# %%
biological_network = {
    "Adcyap1": {"Gli1"},
    "Gli1": {"Ptch1", "Foxa2", "Myf5", "Nkx2-9", "Shh"},
    "Gli2": {"Ptch1", "Fgf15", "Foxe1", "Foxa2", "Myf5", "Gli1"},
    "Gli3": {"Ptch1", "Foxa2", "Myf5", "Gli1", "Shh"},
    "Ihh": {"Gli1"}
}

# %%
### Write your solution here, feel free to add new lines
# One FFL in this network is: ("Gli3", "Gli1", "Shh")
# because we have the following 3 edges: "Gli3", "Gli1" and "Gli1", "Shh" and "Gli3", "Shh"

# %% [markdown]
# ..................................................................................................
#
# #### Part 2 (10 points) - Finding upstream genes in a regulatory network
#
# The following network is represented as a dictionary stored in the variable biological_network in the code cell below.
#
# <img src = Gli_network.png width = 500/>
#
# #### In the network above:
# * Nodes are <mark style="background-color: #9bedff">genes (denoted as rectangles)</mark> or <mark style="background-color: #fbd9d3">transcription factors, TTs (denoted as elipses)</mark>
# * Edges are relations between nodes with the node that the arrow points to being affected/regulated by the node the arrow starts from.
#
# #### The dictionary below is constructed based on the network in the figure above.
# * Keys are the nodes (<mark style="background-color: #9bedff">genes</mark> or <mark style="background-color: #fbd9d3">TFs</mark>) in the network that directly affect/regulate at least one node.
# * Values are the `sets` of nodes the key node directly affects.
#
# #### To be able to check if an element is a gene or a TF we have 2 sets of tuples in the code cell below:
# - one with just genes: `genes`
# - one with just TFs: `transcription_factors`
#
# - <b>(6 points) Write code that computes the SET of TFs that a given GENE is directly regulated by in the network given by the biological_network dictionary </b>
#     - Make proper validations:
#         - e.g.: Make sure to check that the input is really a gene, i.e. is in the genes tuple, and that in the resulting set you only have TFs and not genes
#     - Make use of the functionality available for the data structures you are using
# - <b>(4 points)  Test your code for the following 4 elements: Nkx2-9, Ptch1, Gli1 and Shh </b>
#     - Use a for loop to get the results for each of the tested genes and put them in a dictionary with the key being the elements you test and the value the resulting set
#     - expected result: {'Nkx2-9': {'Gli1'}, 'Ptch1': {'Gli2', 'Gli1', 'Gli3'}, 'Gli1': set(), 'Shh': {'Gli1', 'Gli3'}}

# %%
biological_network = {
    "Adcyap1": {"Gli1"},
    "Gli1": {"Ptch1", "Foxa2", "Myf5", "Nkx2-9", "Shh"},
    "Gli2": {"Ptch1", "Fgf15", "Foxe1", "Foxa2", "Myf5", "Gli1"},
    "Gli3": {"Ptch1", "Foxa2", "Myf5", "Gli1", "Shh"},
    "Ihh": {"Gli1"}
}

# Tuple with the transcription factors in the network (pink elipses in the figure)
transcription_factors = ("Gli1", "Gli2" , "Gli3", "Foxe1", "Foxa2")

# Tuple with the genes in the network (blue boxes in the figure)
genes = ("Fgf15", "Ptch1", "Myf5", "Nkx2-9", "Shh", "Adcyap1", "Ihh")

# %%
# Write your solution here, feel free to add new cells

# %% [markdown]
# ______
# ### Problem 2 - Sequence similarity analysis
# #### 30 points
#
# It is often the case that a bioinformatics analysis require an evaluation of the match between a given sequence and a reference sequence.
# This is the case for genomic sequences but also for protein sequences.
#
# <img src = https://www.researchgate.net/publication/304617437/figure/fig5/AS:668457259528195@1536384038305/Extended-Levenshtein-distance-algorithm-for-matching-two-DNA-sequence-a-mismatch-count.ppm width = "400"/>
#
# https://www.researchgate.net/figure/Extended-Levenshtein-distance-algorithm-for-matching-two-DNA-sequence-a-mismatch-count_fig5_304617437
#
# https://www.nature.com/articles/s41587-018-0010-1
# https://genomebiology.biomedcentral.com/articles/10.1186/s13059-021-02442-8
# https://www.sciencedirect.com/science/article/pii/S0022283620306227
# https://www.pnas.org/doi/abs/10.1073/pnas.2017525118

# %% [markdown]
# ..................................................................................................
#
# #### Part 1 (15 points) - Score sequence similarity
#
#
#
# - Write code that computes a similarity score between two sequences.
#     - The score will be the number of matched elements minus the number of missmatched elements on the respective positions in the two sequences.
#     - If the sequences are of different lengths, each base that does not have a match is a missmatched base
#     - e.g. For the following two sequences: "ACGTG" and "AAGTA" the score will be 1: 3 matches - 2 missmatches
#     - e.g. For the following two sequences: "ACGTC" and "ACGTAA" the score will be 1: 4 matches - 1 missmatch - 1 another missmatch for the last base in the second sequence which is unmatched in the first sequence that is shorter
#
#
# - <b>Score breakdown:</b>
#     - <b>(3 points)</b> Comparing elements available at the same position in the two sequences
#     - <b>(4 points)</b> Accounting for different sequence lengths
#     - <b>(6 points)</b> Accounting for matched and missmatched pairs
#     - <b>(2 points)</b> Testing the code with at least two sets of sequences

# %%
### Write your solution here, feel free to add new lines

# %% [markdown]
# ..................................................................................................
#
# #### Part 2 (15 points) - Identify the best match for one sequence
#
# - Write code to identify the best match from a list of available sequences for a given sequence.
#     - Go through a set of sequences and apply the function built in Part 1 to identify the best match or a given sequence from a set of available sequences.
#     - e.g.: For the following given sequence: "AAACGTTC" and set of sequences: "AACGAT", "CAACGTAC", "AAATGCAAAA", "AAA", "CCGTAACT"
#                 - the best match would be: "CAACGTAC"
#
# - <b>Score breakdown:</b>
#     - <b>(2 point)</b> Comparing the given sequence with each of the elements of the sequence set
#     - <b>(5 points)</b> Using the code from part 1 correctly
#     - <b>(4 points)</b> Identifying the best score
#     - <b>(4 points)</b> Identifying the best sequence

# %%
### Write your solution here, feel free to add new lines

# this is a find maximum problem

# %% [markdown]
# ______
# ### Problem 3 - Process a variant call format file to select variants of interest
# #### 50 points
#
# We have variant data for a sample in the file `variant_data_file.vcf`, which contains information about approximatelly 1000 differences found in the genome (Y chromosome) of the specific sample when compared to the reference.
#
# The description of the format for the vcf file version 4.1 is available in the following document:
# https://samtools.github.io/hts-specs/VCFv4.1.pdf
#
#
# Here is the data for one variant, a line in the vcf file and the header of the vcf file explaining each element on the line.
#
# ```
# #CHROM	POS	ID	        REF	ALT	QUAL FILTER  INFO
# Y	2728456	rs2058276	T	C	32   .       AC=2;AN=2;DB;DP=182;H2;NS=65
# ```

# %% [markdown]
# ..................................................................................................
#
# #### Part 1 (10 points) - Process variant INFO
#
# * <b>(8 points)</b> <b>Write a function to create a dictionary for the INFO part of a variant line. </b>
#     * The input of the function is a string that contains the INFO data for a variant
#         * The INFO string contains keys or key=value pairs separated by semicolon (;).
#         * e.g.: `"AC=2;AN=2;DB;DP=182;H2;NS=65"`
#     * The output of the function should be a dictionary that has the keys and values the same as the keys and values in the INFO data
#         * If a key has no value in the INFO data you should add it to the dictionary with the value `True`
#         * e.g.: the `H2` key has no value <BR><BR>
#
#     *   <b>Score breakdown</b> - these are not ordered steps of an algorithm but just elements of the solution to focus on:
#         - Correctly going through the INFO elements
#             - (2p) first you would need to break them by ; into smaller parts to identify items (key-value pairs)
#             - (2p) then you need to break those pairs by "=" and add the key-value pair to the new dictionary
#             - (2p) you should check if the item has a key and value or just a key
#             - (2p) if it is just a key, add the key-True pair to the new dictionary
#
# * <b>(2 points)</b> <b>Test your function with the following two test INFO strings:</b>
#
# ```python
# test_info1 = "AC=2;AN=2;DB;DP=182;H2;NS=65"
# test_info2 = "AC=1;AN=2;DP=176;NS=60"
# ```

# %%
#Write your solution here, feel free to add new cells.

# One suggestion would be to break down the string into smaller parts and then create dictionary items from them
# The eval solution from homework 3 will not work for all variants, there are keys without values (e.g.: H2)


# DEFINE THE FUNCTION

# %%
# TEST THE FUNCTION

test_info1 = "AC=2;AN=2;DB;DP=182;H2;NS=65"
#### write code here


test_info2 = "AC=1;AN=2;DP=176;NS=60"
#### write code here

# %% [markdown]
# ..................................................................................................
#
# #### Part 2 (20 points) - Check a variant's reliability
#
# - <b>(15 points) Write a function that processes variant information.</b>
#     * The input of the function is a string that contains the data for a variant
#         * It has the format of a data line in the `variant_data_file.vcf`
#             * e.g.: `"Y	2728456	rs2058276	T	C	32	.	AC=2;AN=2;DB;DP=182;H2;NS=65"`
#     * The output of the function should be the rs-identifier if ALL the following 4 conditions are met and `None` otherwise.
#         1. The variant has an identifier
#             - e.g.: rs2058276 is a valid identifier, a missing identifier is denoted by "." as seen in test_variant2 below
#             - the variant identifier is the third element if we break the input string by tab
#         2. The variant has a quality of at least 40 AND
#             - the quality is the sixth element if we break the input string by tab
#         3. The variant has a total read depth higher than 177.
#             - the total read deapth has the key "DP" in the INFO data for the variant
#             - the INFO data is the last element if we break the input string by tab
#         4. The variant is avilable in the HAPMAP2 database
#             - the HAPMAP2 membership is provided by the "H2" key in the INFO data for the variant
#     * Note: The missing identifier value and the thresholds for read depth and quality can be arguments in your function
#         * that can be very useful if you want to allow for flexibility in checking other thresholds. <BR><BR>
#
#     *   <b>Score breakdown</b> - these are not ordered steps of an algorithm but just elements of the solution to focus on:
#         - <b>(15 points)</b> Correctly retrieving relevant variant elements and checking that the 4 conditions are met
#             - (3 points for each condition being checked correctly and 3 points for putting all checks together)
#             - you can retrieve the variant identifier and quality once you break down the variant string, you can use hardoced  idices for that
#             - you can use the function from part1 to create the dictionary from the INFO data and retrieve the total read depth and hapmap2 value
# - <b>(5 points)</b> Test your function with the following 4 test variants and create a results dictionary with the key "variant1" ... "variant4" and the value the rs id if the variant is reliable and None otherwise:</b>
#
# ```bash
# test_variant1 = "Y	2728456	rs2058276	T	C	32	.	AC=2;AN=2;DB;DP=182;H2;NS=65"
# test_variant2 = "Y	7465257	.	A	G	87	.	AC=1;AN=2;DP=176;NS=60"
# test_variant3 = "Y	14886592	rs17222167	A	G	52	.	AC=1;AN=2;DB;DP=199;H2;NS=62"
# test_variant4 = "Y	14864102	rs2319818	G	A	44	.	AC=1;AN=2;DB;DP=202;NS=61"
# ```
# ```python
# # Expected result:
# {"variant1": None, "variant2": None, "variant3": "rs17222167", "variant4": None}
# ```

# %%
# Assume you have a correct function that retrieves the dictionary for the variant
info = "AC=1;AN=2;DB=True;DP=202;NS=61"
eval(f"dict({info.replace(';',',')})")

# %%
# this is a hard-coded function to create the dictionary that you can use for this part only
# if you test with other variants you can add them to this function
def compute_idict(variant):
    d = {}
    if variant == test_variant1:
        d = {'AC': 2, 'AN': 2, 'DB': True, 'DP': 182, 'H2': True, 'NS': 65}
    if variant == test_variant2:
        d = {'AC': 1, 'AN': 2, 'DP': 176, 'NS': 60}
    if variant == test_variant3:
        d = {'AC': 1, 'AN': 2, 'DB': True, 'DP': 199, 'H2': True, 'NS': 62}
    if variant == test_variant4:
        d = {'AC': 1, 'AN': 2, 'DB': True, 'DP': 202, 'NS': 61}
    return d

# %%
# Test the compute_idict function with the 4 variants

test_variant1 = "Y\t2728456\trs2058276\tT\tC\t32\t.\tAC=2;AN=2;DB;DP=182;H2;NS=65"
test_variant2 = "Y\t7465257\t.\tA\tG\t87\t.\tAC=1;AN=2;DP=176;NS=60"
test_variant3 = "Y\t14886592\trs17222167\tA	G\t52\t.\tAC=1;AN=2;DB;DP=199;H2;NS=62"
test_variant4 = "Y\t14864102\trs2319818\tG\tA\t44\t.\tAC=1;AN=2;DB;DP=202;NS=61"

for i in range(1,5):
    v = "test_variant" + str(i)
    d = compute_idict(eval(v))
    print(d)

# %%
# Write your solution here, feel free to add new cells.

# One suggestion would be to break down the string into smaller parts and then look for the features of interest

# DEFINE THE FUNCTION

# %%
# test the function with the 4 variants

# expected result:
# {"variant1": None, "variant2": None, "variant3": "rs17222167", "variant4": None}

# %% [markdown]
# ..................................................................................................
#
#
# #### Part 3 (20 points) - Process a vcf file
#
# * <b> Select from the `variant_data_file.vcf` a set of rs-identifiers that denote the variants that have a quality of at least 40 and a total read depth higher than 200 and are in the HAPMAP2 database. <b>
#
# *   <b>Score breakdown</b> - these are not ordered steps of an algorithm but just elements of the solution to focus on:
#     - <b>(2 points)</b> Writing code that correctly opens the file
#     - <b>(6 points)</b> Writing code that goes through the data/lines in the file ignoring the comment lines and not reading all the file content at once
#     - <b>(6 points)</b> Applying the function created above to the lines that have variant data, or writing code that returns the correct result for each line
#     - <b>(4 points)</b> Corectly building the resulting set of rs identifiers
#     - <b>(2 points)</b> Writing code that ensures the file is closed at the end
#
# Expected result:
# ```python
# {'rs17250177',
#  'rs17250310',
#  'rs17307245',
#  'rs2032652',
#  'rs34194308',
#  'rs3907838',
#  'rs9786420'}
# ```

# %%
#Write your solution here, feel free to add new cells.

# %% [markdown]
# _______
# _______
